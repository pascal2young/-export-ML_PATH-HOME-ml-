# %%
# Common imports
import numpy as np
import pandas as pd
# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# %%
LogDat = pd.read_csv(r"C:\Users\pasca\ML_PATH\Dataset_Dr_Henderson csv.csv")

# %%
LogDat.head()
# Out:
#     DEPTH  Neutron Porosity  Caliper  Density Porosity  Gamma ray  \
# 0  3600.0           29.6276   7.8359           29.0183    26.4565
# 1  3600.5           28.5671   7.8418           28.4555    28.7921
# 2  3601.0           27.1170   7.8434           27.3459    27.4413
# 3  3601.5           24.8582   7.8558           25.3447    25.6896
# 4  3602.0           23.1241   7.8720           22.7096    27.0588
#
#    Photoelectric  Bulk density  Density Correction  Resistivity (Deep)  \
# 0         4.0462        2.2138             -0.0356              0.9126
# 1         4.1226        2.2234             -0.0395              0.8803
# 2         4.2350        2.2424             -0.0362              0.8754
# 3         4.3685        2.2766             -0.0289              0.9005
# 4         4.5133        2.3217             -0.0250              0.9582
#
#    Resistivity (Medium)  ...  Micro-inverse resistivity (micro log)  \
# 0                1.0719  ...                                 5.1127
# 1                1.0008  ...                                 5.0602
# 2                0.9679  ...                                 4.9294
# 3                0.9813  ...                                 5.2303
# 4                1.0502  ...                                 5.2853
#
#    Micro-normal resistivity (micro log)  \
# 0                                7.7722
# 1                                7.4297
# 2                                7.0917
# 3                                7.0816
# 4                                7.2144
#
#    Delta-t (interval transit time, or slowness)  Sonic porosity  \
# 0                                       78.7252         22.0122
# 1                                       78.2474         21.6743
# 2                                       77.6106         21.2239
# 3                                       76.7257         20.5981
# 4                                       75.4503         19.6961
#
#    Type of Formation  Unnamed: 18  NPOR  \
# 0    shaly limestone          NaN  CALI
# 1    shaly limestone          NaN  DPOR
# 2    shaly limestone          NaN    GR
# 3    shaly limestone          NaN    PE
# 4    shaly limestone          NaN  RHOB
#
#   Neutron porosity, calculated assuming a limestone matrix  Unnamed: 21  \
# 0                                            Caliper                NaN
# 1  Density porosity, calculated assuming a limest...                NaN
# 2                                              Gamma                ray
# 3                                      Photoelectric             factor
# 4                                               Bulk            density
#
#   Unnamed: 22
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 23 columns]

# %%
LogDat_adj = LogDat.drop(LogDat.columns[[18,19,20,21,22]], axis=1)  # df.columns is ze

# %%
LogDat_adj.head()
# Out:
#     DEPTH  Neutron Porosity  Caliper  Density Porosity  Gamma ray  \
# 0  3600.0           29.6276   7.8359           29.0183    26.4565
# 1  3600.5           28.5671   7.8418           28.4555    28.7921
# 2  3601.0           27.1170   7.8434           27.3459    27.4413
# 3  3601.5           24.8582   7.8558           25.3447    25.6896
# 4  3602.0           23.1241   7.8720           22.7096    27.0588
#
#    Photoelectric  Bulk density  Density Correction  Resistivity (Deep)  \
# 0         4.0462        2.2138             -0.0356              0.9126
# 1         4.1226        2.2234             -0.0395              0.8803
# 2         4.2350        2.2424             -0.0362              0.8754
# 3         4.3685        2.2766             -0.0289              0.9005
# 4         4.5133        2.3217             -0.0250              0.9582
#
#    Resistivity (Medium)  Resistivity (Shallow)  \
# 0                1.0719                 5.2530
# 1                1.0008                 4.6464
# 2                0.9679                 4.3056
# 3                0.9813                 4.1801
# 4                1.0502                 4.1355
#
#    Ratio (shallow/deep resistivity)  Spontaneous Potential  \
# 0                          -68.4118               -20.3987
# 1                          -65.0243               -19.9382
# 2                          -62.2656               -19.4078
# 3                          -60.0036               -18.7673
# 4                          -57.1585               -17.8640
#
#    Micro-inverse resistivity (micro log)  \
# 0                                 5.1127
# 1                                 5.0602
# 2                                 4.9294
# 3                                 5.2303
# 4                                 5.2853
#
#    Micro-normal resistivity (micro log)  \
# 0                                7.7722
# 1                                7.4297
# 2                                7.0917
# 3                                7.0816
# 4                                7.2144
#
#    Delta-t (interval transit time, or slowness)  Sonic porosity  \
# 0                                       78.7252         22.0122
# 1                                       78.2474         21.6743
# 2                                       77.6106         21.2239
# 3                                       76.7257         20.5981
# 4                                       75.4503         19.6961
#
#   Type of Formation
# 0   shaly limestone
# 1   shaly limestone
# 2   shaly limestone
# 3   shaly limestone
# 4   shaly limestone

# %%
LogDat_adj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1989 entries, 0 to 1988
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   DEPTH                                         1989 non-null   float64
#  1   Neutron Porosity                              1989 non-null   float64
#  2   Caliper                                       1989 non-null   float64
#  3   Density Porosity                              1989 non-null   float64
#  4   Gamma ray                                     1989 non-null   float64
#  5   Photoelectric                                 1989 non-null   float64
#  6   Bulk density                                  1989 non-null   float64
#  7   Density Correction                            1989 non-null   float64
#  8   Resistivity (Deep)                            1989 non-null   float64
#  9   Resistivity (Medium)                          1989 non-null   float64
#  10  Resistivity (Shallow)                         1989 non-null   float64
#  11  Ratio (shallow/deep resistivity)              1989 non-null   float64
#  12  Spontaneous Potential                         1989 non-null   float64
#  13  Micro-inverse resistivity (micro log)         1989 non-null   float64
#  14  Micro-normal resistivity (micro log)          1989 non-null   float64
#  15  Delta-t (interval transit time, or slowness)  1989 non-null   float64
#  16  Sonic porosity                                1989 non-null   float64
#  17  Type of Formation                             1936 non-null   object
# dtypes: float64(17), object(1)
# memory usage: 279.8+ KB

# %%
LogDat_adj.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'DEPTH'}>,
#         <AxesSubplot:title={'center':'Neutron Porosity'}>,
#         <AxesSubplot:title={'center':'Caliper'}>,
#         <AxesSubplot:title={'center':'Density Porosity'}>],
#        [<AxesSubplot:title={'center':'Gamma ray'}>,
#         <AxesSubplot:title={'center':'Photoelectric'}>,
#         <AxesSubplot:title={'center':'Bulk density'}>,
#         <AxesSubplot:title={'center':'Density Correction'}>],
#        [<AxesSubplot:title={'center':'Resistivity (Deep)'}>,
#         <AxesSubplot:title={'center':'Resistivity (Medium)'}>,
#         <AxesSubplot:title={'center':'Resistivity (Shallow)'}>,
#         <AxesSubplot:title={'center':'Ratio (shallow/deep resistivity)'}>],
#        [<AxesSubplot:title={'center':'Spontaneous Potential'}>,
#         <AxesSubplot:title={'center':'Micro-inverse resistivity (micro log)'}>,
#         <AxesSubplot:title={'center':'Micro-normal resistivity (micro log)'}>,
#         <AxesSubplot:title={'center':'Delta-t (interval transit time, or slowness)'}>],
#        [<AxesSubplot:title={'center':'Sonic porosity'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
EPTH  Neutron Porosity  Caliper  Density Porosity  Gamma ray  \
# 0  3600.0           29.6276   7.8359           29.0183    26.4565
# 1  3600.5           28.5671   7.8418           28.4555    28.7921
# 2  3601.0           27.1170   7.8434           27.3459    27.4413
# 3  3601.5           24.8582   7.8558           25.3447    25.6896
# 4  3602.0           23.1241   7.8720           22.7096    27.0588
#
#    Photoelectric  Bulk density  Density Correction  Resistivity (Deep)  \
# 0         4.0462        2.2138             -0.0356              0.9126
# 1         4.1226        2.2234             -0.0395              0.8803
# 2         4.2350        2.2424             -0.0362              0.8754
# 3         4.3685        2.2766             -0.0289              0.9005
# 4         4.5133        2.3217             -0.0250              0.9582
#
#    Resistivity (Medium)  Resistivity (Shallow)  \
# 0                1.0719                 5.2530
# 1                1.0008                 4.6464
# 2                0.9679                 4.3056
# 3                0.9813                 4.1801
# 4                1.0502                 4.1355
#
#    Ratio (shallow/deep resistivity)  Spontaneous Potential  \
# 0                          -68.4118               -20.3987
# 1                          -65.0243               -19.9382
# 2                          -62.2656               -19.4078
# 3                          -60.0036               -18.7673
# 4                          -57.1585               -17.8640
#
#    Micro-inverse resistivity (micro log)  \
# 0                                 5.1127
# 1                                 5.0602
# 2                                 4.9294
# 3                                 5.2303
# 4                                 5.2853
#
#    Micro-normal resistivity (micro log)  \
# 0                                7.7722
# 1                                7.4297
# 2                                7.0917
# 3                                7.0816
# 4                                7.2144
#
#    Delta-t (interval transit time, or slowness)  Sonic porosity  \
# 0                                       78.7252         22.0122
# 1                                       78.2474         21.6743
# 2                                       77.6106         21.2239
# 3                                       76.7257         20.5981
# 4                                       75.4503         19.6961
#
#   Type of Formation
# 0   shaly limestone
# 1   shaly limestone
# 2   shaly limestone
# 3   shaly limestone
# 4   shaly limestone

# %% [markdown]
# # Creating a Test Set

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(test_size=0.2,  random_state=42)
for train_index, test_index in split.split(LogDat_drop, LogDat_drop["Type of Formation"]):
    strat_train_set = LogDat_drop.loc[train_index]
    strat_test_set = LogDat_drop.loc[test_index]

# %%
strat_train_set
# Out:
#        DEPTH  Neutron Porosity  Caliper  Density Porosity  Gamma ray  \
# 862   4031.0           23.7803  10.3097           27.2087    89.4621
# 1416  4308.0            9.2509   7.9421            5.4870    36.6526
# 417   3808.5           16.9401   7.7745           16.2388    43.9592
# 182   3691.0           17.7510   8.5244           14.3038    88.6786
# 1836  4518.0           11.9549   7.6834            2.3894    24.1435
# ...      ...               ...      ...               ...        ...
# 1848  4524.0           17.4797   7.6366           11.1470    33.2406
# 1534  4367.0           15.6098   8.2340            7.6942    94.2904
# 428   3814.0           14.2060   7.9901           15.2368    51.5470
# 1691  4445.5           24.5646   8.5297           25.8334   104.4840
# 852   4026.0            3.5946   7.9432            4.5252    38.1114
#
#       Photoelectric  Bulk density  Density Correction  Resistivity (Deep)  \
#
photoelectric  Bulk density  Density Correction  Resistivity (Deep)  \
# 862          3.0931        2.2447              0.1717              3.7613
# 1416         3.7417        2.6162             -0.0104             12.8723
# 417          4.4858        2.4323             -0.0353              1.6243
# 182          4.2362        2.4654             -0.0765              3.4288
# 1836         4.2796        2.6691              0.0050             10.5432
#
#       Resistivity (Medium)  Resistivity (Shallow)  \
# 862                 3.1427                 4.2700
# 1416               14.1670                17.9083
# 417                 1.9432                 7.6253
# 182                 3.5282                 4.3340
# 1836               13.3627                43.7569
#
#       Ratio (shallow/deep resistivity)  Spontaneous Potential  \
# 862                            -4.9586                58.4931
# 1416                          -12.9058                76.3179
# 417                           -60.4443               -12.6482
# 182                            -9.1571                54.0127
# 1836                          -55.6267                30.2873
#
#       Micro-inverse resistivity (micro log)  \
# 862                                  2.0651
# 1416                                19.7103
# 417                                  6.5615
# 182                                  7.1606
# 1836                                 8.5436
#
#       Micro-normal resistivity (micro log)  \
# 862                                 1.9967
# 1416                               17.1852
# 417                                 9.9651
# 182                                 5.8614
# 1836                               15.5226
#
#       Delta-t (interval transit time, or slowness)  Sonic porosity  \
# 862                                        85.5483         26.8375
# 1416                                       63.2834         11.0915
# 417                                        68.5809         14.8380
# 182                                        75.2756         19.5726
# 1836                                       57.7738          7.1950
#
#      Type of Formation
# 862    shaly limestone
# 1416         limestone
# 417          limestone
# 182    shaly limestone
# 1836          dolomite

# %%
dataset_preprocessed = pd.get_dummies(dataset)
dataset_preprocessed.head()
# Out:
#        DEPTH  Neutron Porosity  Caliper  Density Porosity  Gamma ray  \
# 862   4031.0           23.7803  10.3097           27.2087    89.4621
# 1416  4308.0            9.2509   7.9421            5.4870    36.6526
# 417   3808.5           16.9401   7.7745           16.2388    43.9592
# 182   3691.0           17.7510   8.5244           14.3038    88.6786
# 1836  4518.0           11.9549   7.6834            2.3894    24.1435
#
#       Photoelectric  Bulk density  Density Correction  Resistivity (Deep)  \
# 862          3.0931        2.2447              0.1717              3.7613
# 1416         3.7417        2.6162             -0.0104             12.8723
# 417          4.4858        2.4323             -0.0353              1.6243
# 182          4.2362        2.4654             -0.0765              3.4288
# 1836         4.2796        2.6691              0.0050             10.5432
#
#       Resistivity (Medium)  ...  Micro-normal resistivity (micro log)  \
# 862                 3.1427  ...                                1.9967
# 1416               14.1670  ...                               17.1852
# 417                 1.9432  ...                                9.9651
# 182                 3.5282  ...                                5.8614
# 1836               13.3627  ...                               15.5226
#
#       Delta-t (interval transit time, or slowness)  Sonic porosity  \
# 862                                        85.5483         26.8375
# 1416                                       63.2834         11.0915
# 417                                        68.5809         14.8380
# 182                                        75.2756         19.5726
# 1836                                       57.7738          7.1950
#
#       Type of Formation_dolomite  Type of Formation_limestone  \
# 862                            0                            0
# 1416                           0                            1
# 417                            0                            1
# 182                            0                            0
# 1836                           1                            0
#
#       Type of Formation_sandstone  Type of Formation_sandy limestone  \
# 862                             0                                  0
# 1416                            0                                  0
# 417                             0                                  0
# 182                             0                                  0
# 1836                            0                                  0
#
#       Type of Formation_shale  Type of Formation_shaly limestone  \
# 862                         0                                  1
# 1416                        0                                  0
# 417                         0                                  0
# 182                         0                                  1
# 1836                        0                                  0
#
#       Type of Formation_shaly sandstone
# 862                                   0
# 1416                                  0
# 417                                   0
# 182                                   0
# 1836                                  0
#
# [5 rows x 24 columns]

# %%
train_preprocessed = dataset_preprocessed[:train_objs_num]
train_preprocessed.head()
# Out:
#        DEPTH  Neutron Porosity  Caliper  Density Porosity  Gamma ray  \
#
labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 381 entries, 534 to 1619
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Type of Formation_dolomite         381 non-null    uint8
#  1   Type of Formation_limestone        381 non-null    uint8
#  2   Type of Formation_sandstone        381 non-null    uint8
#  3   Type of Formation_sandy limestone  381 non-null    uint8
#  4   Type of Formation_shale            381 non-null    uint8
#  5   Type of Formation_shaly limestone  381 non-null    uint8
#  6   Type of Formation_shaly sandstone  381 non-null    uint8
# dtypes: uint8(7)
# memory usage: 5.6 KB

# %%
LogDat_test_labels.sum()
# Out:
# Type of Formation_dolomite            26
# Type of Formation_limestone          191
# Type of Formation_sandstone           12
# Type of Formation_sandy limestone      8
# Type of Formation_shale               52
# Type of Formation_shaly limestone     91
# Type of Formation_shaly sandstone      1
# dtype: int64

# %%
LogDat_train_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1524 entries, 862 to 852
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Type of Formation_dolomite         1524 non-null   uint8
#  1   Type of Formation_limestone        1524 non-null   uint8
#  2   Type of Formation_sandstone        1524 non-null   uint8
#  3   Type of Formation_sandy limestone  1524 non-null   uint8
#  4   Type of Formation_shale            1524 non-null   uint8
#  5   Type of Formation_shaly limestone  1524 non-null   uint8
#  6   Type of Formation_shaly sandstone  1524 non-null   uint8
# dtypes: uint8(7)
# memory usage: 22.3 KB

# %%
LogDat_train_labels.sum()
# Out:
# Type of Formation_dolomite           106
# Type of Formation_limestone          765
# Type of Formation_sandstone           47
# Type of Formation_sandy limestone     30
# Type of Formation_shale              206
# Type of Formation_shaly limestone    365
# Type of Formation_shaly sandstone      5
# dtype: int64

# %% [markdown]
# # Data Visualization after Cleaning the Data

# %%
LogDat_drop.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'DEPTH'}>,
#         <AxesSubplot:title={'center':'Neutron Porosity'}>,
#         <AxesSubplot:title={'center':'Caliper'}>,
#         <AxesSubplot:title={'center':'Density Porosity'}>],
#        [<AxesSubplot:title={'center':'Gamma ray'}>,
#         <AxesSubplot:title={'center':'Photoelectric'}>,
#         <AxesSubplot:title={'center':'Bulk density'}>,
#         <AxesSubplot:title={'center':'Density Correction'}>],
#        [<AxesSubplot:title={'center':'Resistivity (Deep)'}>,
#         <AxesSubplot:title={'center':'Resistivity (Medium)'}>,
#         <AxesSubplot:title={'center':'Resistivity (Shallow)'}>,
#         <AxesSubplot:title={'center':'Ratio (shallow/deep resistivity)'}>],
#        [<AxesSubplot:title={'center':'Spontaneous Potential'}>,
#         <AxesSubplot:title={'center':'Micro-inverse resistivity (micro log)'}>,
#         <AxesSubplot:title={'center':'Micro-normal resistivity (micro log)'}>,
#         <AxesSubplot:title={'center':'Delta-t (interval transit time, or slowness)'}>],
#        [<AxesSubplot:title={'center':'Sonic porosity'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
LogDat_train_new.plot(kind = "scatter", x ="Density Porosity", y ="DEPTH",grid = True, xlim=[-5,40],
                    alpha =0.1)
# Out:
# <AxesSubplot:xlabel='Density Porosity', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Neutron Porosity", y ="DEPTH",grid = True, xlim=[0,40],alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Neutron Porosity', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Sonic porosity", y ="DEPTH",grid = True, xlim=[0,45],alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Sonic porosity', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Caliper", y ="DEPTH",grid = True, xlim=[7,11],alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Caliper', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Gamma ray", y ="DEPTH",grid = True, xlim=[-10,360],alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Gamma ray', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Resistivity (Deep)", y ="DEPTH",grid = True, xlim=[0,110]
                    ,alpha =0.1)
# Out:
# <AxesSubplot:xlabel='Resistivity (Deep)', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Resistivity (Medium)", y ="DEPTH",grid = True, xlim=[-20,300]
                    ,alpha =0.1)
# Out:
# <AxesSubplot:xlabel='Resistivity (Medium)', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Resistivity (Shallow)", y ="DEPTH",grid = True, xlim=[-20,800]
                    ,alpha =0.1)
# Out:
# <AxesSubplot:xlabel='Resistivity (Shallow)', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Photoelectric", y ="DEPTH",grid = True, xlim=[1,7],alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Photoelectric', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Spontaneous Potential", y ="DEPTH",grid = True, xlim=[-25,95],alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Spontaneous Potential', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Bulk density", y ="DEPTH",grid = True, xlim=[2,2.8],alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Bulk density', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Micro-inverse resistivity (micro log)", y ="DEPTH",grid = True, xlim=[0,65]
                    ,alpha=0.1) #Off-point on the left again in this log as well
# Out:
# <AxesSubplot:xlabel='Micro-inverse resistivity (micro log)', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Micro-normal resistivity (micro log)", y ="DEPTH",grid = True, xlim=[0,60]
                    ,alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Micro-normal resistivity (micro log)', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Delta-t (interval transit time, or slowness)", y ="DEPTH",grid = True, 
                     xlim=[45,110], alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Delta-t (interval transit time, or slowness)', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Density Correction", y ="DEPTH",grid = True, 
                     xlim=[-0.1,0.3], alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Density Correction', ylabel='DEPTH'>

# %%
LogDat_train_new.plot(kind = "scatter", x ="Ratio (shallow/deep resistivity)", y ="DEPTH",grid = True, 
                     xlim=[-170,50], alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Ratio (shallow/deep resistivity)', ylabel='DEPTH'>

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()
LogDat_train_copy = LogDat_train_num.copy()
LogDat_train_scaled = std_scaler.fit_transform(LogDat_train_copy)
LogDat_train_scaled
# Out:
# array([[-0.16648066,  1.25727151,  5.97285585, ..., -1.25975312,
#          1.61868884,  1.61868142],
#        [ 0.83963908, -0.77896184, -0.30888761, ...,  0.37127594,
#         -0.51964662, -0.51964886],
#        [-0.97464543,  0.2986467 , -0.75356585, ..., -0.4040602 ,
#         -0.01087128, -0.01086857],
#        ...,
#        [-0.95466832, -0.08452574, -0.18153346, ...,  0.15598891,
#         -0.24356817, -0.24356443],
#        [ 1.33906675,  1.36718781,  1.25013945, ..., -1.11117414,
#          1.53817797,  1.5381783 ],
#        [-0.18464166, -1.57166813, -0.30596908, ...,  0.87349779,
#         -1.46557979, -1.46557415]])

# %% [raw]
# Final training and test sets after standard scaling

# %%
X_train = LogDat_train_scaled

# %%
X_train.shape
# Out:
# (1524, 17)

# %%
X_train
# Out:
# array([[-0.16648066,  1.25727151,  5.97285585, ..., -1.25975312,
#          1.61868884,  1.61868142],
#        [ 0.83963908, -0.77896184, -0.30888761, ...,  0.37127594,
#         -0.51964662, -0.51964886],
#        [-0.97464543,  0.2986467 , -0.75356585, ..., -0.4040602 ,
#         -0.01087128, -0.01086857],
#        ...,
#        [-0.95466832, -0.08452574, -0.18153346, ...,  0.15598891,
#         -0.24356817, -0.24356443],
#        [ 1.33906675,  1.36718781,  1.25013945, ..., -1.11117414,
#          1.53817797,  1.5381783 ],
#        [-0.18464166, -1.57166813, -0.30596908, ...,  0.87349779,
#         -1.46557979, -1.46557415]])

# %%
y_train = LogDat_train_labels.copy()
y_train.head()
# Out:
#       Type of Formation_dolomite  Type of Formation_limestone  \
# 862                            0                            0
# 1416                           0                            1
# 417                            0                            1
# 182                            0                            0
# 1836                           1                            0
#
#       Type of Formation_sandstone  Type of Formation_sandy limestone  \
# 862                             0                                  0
# 1416                            0                                  0
# 417                             0                                  0
# 182                             0                                  0
# 1836                            0                                  0
#
#       Type of Formation_shale  Type of Formation_shaly limestone  \
# 862                         0                                  1
# 1416                        0                                  0
# 417                         0                                  0
# 182                         0                                  1
# 1836                        0                                  0
#
#       Type of Formation_shaly sandstone
# 862                                   0
# 1416                                  0
# 417                                   0
# 182                                   0
# 1836                                  0

# %%
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1524 entries, 862 to 852
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Type of Formation_dolomite         1524 non-null   uint8
#  1   Type of Formation_limestone        1524 non-null   uint8
#  2   Type of Formation_sandstone        1524 non-null   uint8
#  3   Type of Formation_sandy limestone  1524 non-null   uint8
#  4   Type of Formation_shale            1524 non-null   uint8
#  5   Type of Formation_shaly limestone  1524 non-null   uint8
#  6   Type of Formation_shaly sandstone  1524 non-null   uint8
# dtypes: uint8(7)
# memory usage: 22.3 KB

# %%
y_train.shape
# Out:
# (1524, 7)

# %%
X_test_new = LogDat_test_num.copy()
X_test_new.head()
# Out:
#        DEPTH  Neutron Porosity  Caliper  Density Porosity  Gamma ray  \
# 534   3867.0           24.1741   8.8235           20.6195    93.1156
# 1405  4302.5            9.9280   7.9147            5.7373    39.1027
# 1821  4510.5           14.3703   7.7998            3.7541    30.7984
# 231   3715.5           14.2481   7.9007           12.0989    36.9107
# 1045  4122.5            7.2925   7.9864            8.3695    39.6763
#
#       Photoelectric  Bulk density  Density Correction  Resistivity (Deep)  \
# 534          2.7633        2.3574              0.1315              2.1999
# 1405         4.3540        2.6119             -0.0196             13.1032
# 1821         4.0583        2.6458              0.0157             11.3261
# 231          4.0388        2.5031             -0.0164              2.6596
# 1045         4.3900        2.5669             -0.0383             17.1987
#
#       Resistivity (Medium)  Resistivity (Shallow)  \
# 534                 2.1223                 2.9073
# 1405               14.3543                18.2093
# 1821               14.7708                32.9344
# 231                 3.5011                13.4128
# 1045               17.3891                14.4154
#
#       Ratio (shallow/deep resistivity)  Spontaneous Potential  \
# 534                           -10.8972                59.3345
# 1405                          -12.8624                73.3173
# 1821                          -41.7214                32.7454
# 231                           -63.2430                -3.3619
# 1045                            6.9002                51.5478
#
#       Micro-inverse resistivity (micro log)  \
# 534                                  2.0045
# 1405                                18.1106
# 1821                                17.7039
# 231                                  7.0907
# 1045                                16.7561
#
#       Micro-normal resistivity (micro log)  \
# 534                                 1.9051
# 1405                               13.4501
# 1821                               19.2582
# 231                                10.8483
# 1045                               17.8185
#
#       Delta-t (interval transit time, or slowness)  Sonic porosity
# 534                                        91.2177         30.8471
# 1405                                       63.5973         11.3135
# 1821                                       59.1972          8.2017
# 231                                        65.4046         12.5916
# 1045                                       60.4761          9.1062

# %%
X_test_prepared = std_scaler.transform(X_test_new)
X_test_prepared
# Out:
# array([[-0.76216166,  1.3124609 ,  2.02965297, ..., -1.26958966,
#          2.1631817 ,  2.16319108],
#        [ 0.81966198, -0.68406917, -0.3815856 , ..., -0.02982072,
#         -0.48949946, -0.48950093],
#        [ 1.57515983, -0.0614998 , -0.6864396 , ...,  0.59388668,
#         -0.91208792, -0.91208801],
#        ...,
#        [ 1.34814725,  0.39604798,  0.26022625, ..., -0.62394334,
#          1.01548633,  1.01549194],
#        [-0.5968965 , -1.18359059, -0.06558812, ...,  2.73192699,
#         -1.30964819, -1.30964688],
#        [ 1.20830751, -1.43358255, -0.43464983, ...,  1.96500991,
#         -1.2236726 , -1.22367095]])

# %%
y_test_new = LogDat_test_labels.copy()
y_test_new.head()
# Out:
#       Type of Formation_dolomite  Type of Formation_limestone  \
# 534                            0                            0
# 1405                           0                            1
# 1821                           1                            0
# 231                            0                            1
# 1045                           0                            1
#
#       Type of Formation_sandstone  Type of Formation_sandy limestone  \
# 534                             0                                  0
# 1405                            0                                  0
# 1821                            0                                  0
# 231                             0                                  0
# 1045                            0                                  0
#
#       Type of Formation_shale  Type of Formation_shaly limestone  \
# 534                         0                                  1
# 1405                        0                                  0
# 1821                        0                                  0
# 231                         0                                  0
# 1045                        0                                  0
#
#       Type of Formation_shaly sandstone
# 534                                   0
# 1405                                  0
# 1821                                  0
# 231                                   0
# 1045                                  0

# %%
y_train.sum()
# Out:
# Type of Formation_dolomite           106
# Type of Formation_limestone          765
# Type of Formation_sandstone           47
# Type of Formation_sandy limestone     30
# Type of Formation_shale              206
# Type of Formation_shaly limestone    365
# Type of Formation_shaly sandstone      5
# dtype: int64

# %%
y_test_new.sum()
# Out:
# Type of Formation_dolomite            26
# Type of Formation_limestone          191
# Type of Formation_sandstone           12
# Type of Formation_sandy limestone      8
# Type of Formation_shale               52
# Type of Formation_shaly limestone     91
# Type of Formation_shaly sandstone      1
# dtype: int64

# %%
y_train_sl = y_train["Type of Formation_shaly limestone"]
y_train_sl.head()
# Out:
# 862     1
# 1416    0
# 417     0
# 182     1
# 1836    0
# Name: Type of Formation_shaly limestone, dtype: uint8

# %%
y_train_sl.shape
# Out:
# (1524,)

# %%
y_test_sl = y_test_new["Type of Formation_shaly limestone"]
y_test_sl.head()
# Out:
# 534     1
# 1405    0
# 1821    0
# 231     0
# 1045    0
# Name: Type of Formation_shaly limestone, dtype: uint8

# %%
y_test_sl.shape
# Out:
# (381,)

# %% [markdown]
# # Feature relationships that might be helpful for dimensionality reduction

# %%
corr_matrix = LogDat_train_new.corr()
corr_matrix
# Out:
#                                                  DEPTH  Neutron Porosity  \
# DEPTH                                         1.000000          0.023852
# Neutron Porosity                              0.023852          1.000000
# Caliper                                      -0.152598          0.358103
# Density Porosity                              0.011147          0.794491
# Gamma ray                                    -0.022132          0.487249
# Photoelectric                                -0.422791         -0.610505
# Bulk density                                 -0.011469         -0.795099
# Density Correction                            0.300642          0.374814
# Resistivity (Deep)                            0.179836         -0.531118
# Resistivity (Medium)                          0.079711         -0.477005
# Resistivity (Shallow)                         0.097527         -0.498703
# Ratio (shallow/deep resistivity)              0.318618          0.330358
# Spontaneous Potential                         0.525820         -0.016574
# Micro-inverse resistivity (micro log)        -0.014616         -0.771518
# Micro-normal resistivity (micro log)         -0.026696         -0.787190
# Delta-t (interval transit time, or slowness)  0.088158          0.867594
# Sonic porosity                                0.088158          0.867594
#
#                                                Caliper  Density Porosity  \
# DEPTH                                        -0.152598          0.011147
# Neutron Porosity                              0.358103          0.794491
# Caliper                                       1.000000          0.251952
# Density Porosity                              0.251952          1.000000
# Gamma ray                                     0.491171          0.362680
# Photoelectric                                -0.159168         -0.726447
# Bulk density                                 -0.251562         -0.999898
# Density Correction                            0.400607          0.379041
# Resistivity (Deep)                           -0.105817         -0.389429
# Resistivity (Medium)                         -0.073930         -0.353246
# Resistivity (Shallow)                        -0.119004         -0.374432
# Ratio (shallow/deep resistivity)              0.335348          0.218336
# Spontaneous Potential                         0.351323         -0.190248
# Micro-inverse resistivity (micro log)        -0.170491         -0.663478
# Micro-normal resistivity (micro log)         -0.266057         -0.640060
# Delta-t (interval transit time, or slowness)  0.479877          0.736503
# Sonic porosity                                0.479877          0.736503
#
#                                               Gamma ray  Photoelectric  \
# DEPTH                                         -0.022132      -0.422791
# Neutron Porosity                               0.487249      -0.610505
# Caliper                                        0.491171      -0.159168
# Density Porosity                               0.362680      -0.726447
# Gamma ray                                      1.000000      -0.290398
# Photoelectric                                 -0.290398       1.000000
# Bulk density                                  -0.362673       0.726764
# Density Correction                             0.382939      -0.586295
# Resistivity (Deep)                            -0.206076       0.346639
# Resistivity (Medium)                          -0.190794       0.360490
# Resistivity (Shallow)                         -0.181926       0.370423
# Ratio (shallow/deep resistivity)               0.312570      -0.419717
# Spontaneous Potential                          0.399312      -0.146626
# Micro-inverse resistivity (micro log)         -0.245407       0.593197
# Micro-normal resistivity (micro log)          -0.358233       0.616855
# Delta-t (interval transit time, or slowness)   0.685225      -0.661368
# Sonic porosity                                 0.685225      -0.661368
#
#                                               Bulk density  \
# DEPTH                                            -0.011469
# Neutron Porosity                                 -0.795099
# Caliper                                          -0.251562
# Density Porosity                                 -0.999898
# Gamma ray                                        -0.362673
# Photoelectric                                     0.726764
# Bulk density                                      1.000000
# Density Correction                               -0.379058
# Resistivity (Deep)                                0.391139
# Resistivity (Medium)                              0.356768
# Resistivity (Shallow)                             0.377474
# Ratio (shallow/deep resistivity)                 -0.219575
# Spontaneous Potential                             0.189533
# Micro-inverse resistivity (micro log)             0.664714
# Micro-normal resistivity (micro log)              0.641591
# Delta-t (interval transit time, or slowness)     -0.736914
# Sonic porosity                                   -0.736914
#
#                                               Density Correction  \
# DEPTH                                                   0.300642
# Neutron Porosity                                        0.374814
# Caliper                                                 0.400607
# Density Porosity                                        0.379041
# Gamma ray                                               0.382939
# Photoelectric                                          -0.586295
# Bulk density                                           -0.379058
# Density Correction                                      1.000000
# Resistivity (Deep)                                     -0.259043
# Resistivity (Medium)                                   -0.254700
# Resistivity (Shallow)                                  -0.207793
# Ratio (shallow/deep resistivity)                        0.267328
# Spontaneous Potential                                   0.315578
# Micro-inverse resistivity (micro log)                  -0.372762
# Micro-normal resistivity (micro log)                   -0.406183
# Delta-t (interval transit time, or slowness)            0.528873
# Sonic porosity                                          0.528873
#
#                                               Resistivity (Deep)  \
# DEPTH                                                   0.179836
# Neutron Porosity                                       -0.531118
# Caliper                                                -0.105817
# Density Porosity                                       -0.389429
# Gamma ray                                              -0.206076
# Photoelectric                                           0.346639
# Bulk density                                            0.391139
# Density Correction                                     -0.259043
# Resistivity (Deep)                                      1.000000
# Resistivity (Medium)                                    0.872303
# Resistivity (Shallow)                                   0.578910
# Ratio (shallow/deep resistivity)                        0.019873
# Spontaneous Potential                                   0.056309
# Micro-inverse resistivity (micro log)                   0.620202
# Micro-normal resistivity (micro log)                    0.619777
# Delta-t (interval transit time, or slowness)           -0.505506
# Sonic porosity                                         -0.505506
#
#                                               Resistivity (Medium)  \
# DEPTH                                                     0.079711
# Neutron Porosity                                         -0.477005
# Caliper                                                  -0.073930
# Density Porosity                                         -0.353246
# Gamma ray                                                -0.190794
# Photoelectric                                             0.360490
# Bulk density                                              0.356768
# Density Correction                                       -0.254700
# Resistivity (Deep)                                        0.872303
# Resistivity (Medium)                                      1.000000
# Resistivity (Shallow)                                     0.664246
# Ratio (shallow/deep resistivity)                         -0.115396
# Spontaneous Potential                                    -0.034065
# Micro-inverse resistivity (micro log)                     0.589020
# Micro-normal resistivity (micro log)                      0.597413
# Delta-t (interval transit time, or slowness)             -0.461181
# Sonic porosity                                           -0.461181
#
#                                               Resistivity (Shallow)  \
# DEPTH                                                      0.097527
# Neutron Porosity                                          -0.498703
# Caliper                                                   -0.119004
# Density Porosity                                          -0.374432
# Gamma ray                                                 -0.181926
# Photoelectric                                              0.370423
# Bulk density                                               0.377474
# Density Correction                                        -0.207793
# Resistivity (Deep)                                         0.578910
# Resistivity (Medium)                                       0.664246
# Resistivity (Shallow)                                      1.000000
# Ratio (shallow/deep resistivity)                          -0.510790
# Spontaneous Potential                                      0.009546
# Micro-inverse resistivity (micro log)                      0.623944
# Micro-normal resistivity (micro log)                       0.699602
# Delta-t (interval transit time, or slowness)              -0.455882
# Sonic porosity                                            -0.455882
#
#                                               Ratio (shallow/deep resistivity)  \
# DEPTH                                                                 0.318618
# Neutron Porosity                                                      0.330358
# Caliper                                                               0.335348
# Density Porosity                                                      0.218336
# Gamma ray                                                             0.312570
# Photoelectric                                                        -0.419717
# Bulk density                                                         -0.219575
# Density Correction                                                    0.267328
# Resistivity (Deep)                                                    0.019873
# Resistivity (Medium)                                                 -0.115396
# Resistivity (Shallow)                                                -0.510790
# Ratio (shallow/deep resistivity)                                      1.000000
# Spontaneous Potential                                                 0.461031
# Micro-inverse resistivity (micro log)                                -0.349230
# Micro-normal resistivity (micro log)                                 -0.506957
# Delta-t (interval transit time, or slowness)                          0.395101
# Sonic porosity                                                        0.395101
#
#                                               Spontaneous Potential  \
# DEPTH                                                      0.525820
# Neutron Porosity                                          -0.016574
# Caliper                                                    0.351323
# Density Porosity                                          -0.190248
# Gamma ray                                                  0.399312
# Photoelectric                                             -0.146626
# Bulk density                                               0.189533
# Density Correction                                         0.315578
# Resistivity (Deep)                                         0.056309
# Resistivity (Medium)                                      -0.034065
# Resistivity (Shallow)                                      0.009546
# Ratio (shallow/deep resistivity)                           0.461031
# Spontaneous Potential                                      1.000000
# Micro-inverse resistivity (micro log)                      0.086512
# Micro-normal resistivity (micro log)                      -0.063368
# Delta-t (interval transit time, or slowness)               0.263632
# Sonic porosity                                             0.263632
#
#                                               Micro-inverse resistivity (micro log)  \
# DEPTH                                                                     -0.014616
# Neutron Porosity                                                          -0.771518
# Caliper                                                                   -0.170491
# Density Porosity                                                          -0.663478
# Gamma ray                                                                 -0.245407
# Photoelectric                                                              0.593197
# Bulk density                                                               0.664714
# Density Correction                                                        -0.372762
# Resistivity (Deep)                                                         0.620202
# Resistivity (Medium)                                                       0.589020
# Resistivity (Shallow)                                                      0.623944
# Ratio (shallow/deep resistivity)                                          -0.349230
# Spontaneous Potential                                                      0.086512
# Micro-inverse resistivity (micro log)                                      1.000000
# Micro-normal resistivity (micro log)                                       0.920371
# Delta-t (interval transit time, or slowness)                              -0.675558
# Sonic porosity                                                            -0.675558
#
#                                               Micro-normal resistivity (micro log)  \
# DEPTH                                                                    -0.026696
# Neutron Porosity                                                         -0.787190
# Caliper                                                                  -0.266057
# Density Porosity                                                         -0.640060
# Gamma ray                                                                -0.358233
# Photoelectric                                                             0.616855
# Bulk density                                                              0.641591
# Density Correction                                                       -0.406183
# Resistivity (Deep)                                                        0.619777
# Resistivity (Medium)                                                      0.597413
# Resistivity (Shallow)                                                     0.699602
# Ratio (shallow/deep resistivity)                                         -0.506957
# Spontaneous Potential                                                    -0.063368
# Micro-inverse resistivity (micro log)                                     0.920371
# Micro-normal resistivity (micro log)                                      1.000000
# Delta-t (interval transit time, or slowness)                             -0.748688
# Sonic porosity                                                           -0.748689
#
#                                               Delta-t (interval transit time, or slowness)  \
# DEPTH                                                                             0.088158
# Neutron Porosity                                                                  0.867594
# Caliper                                                                           0.479877
# Density Porosity                                                                  0.736503
# Gamma ray                                                                         0.685225
# Photoelectric                                                                    -0.661368
# Bulk density                                                                     -0.736914
# Density Correction                                                                0.528873
# Resistivity (Deep)                                                               -0.505506
# Resistivity (Medium)                                                             -0.461181
# Resistivity (Shallow)                                                            -0.455882
# Ratio (shallow/deep resistivity)                                                  0.395101
# Spontaneous Potential                                                             0.263632
# Micro-inverse resistivity (micro log)                                            -0.675558
# Micro-normal resistivity (micro log)                                             -0.748688
# Delta-t (interval transit time, or slowness)                                      1.000000
# Sonic porosity                                                                    1.000000
#
#                                               Sonic porosity
# DEPTH                                               0.088158
# Neutron Porosity                                    0.867594
# Caliper                                             0.479877
# Density Porosity                                    0.736503
# Gamma ray                                           0.685225
# Photoelectric                                      -0.661368
# Bulk density                                       -0.736914
# Density Correction                                  0.528873
# Resistivity (Deep)                                 -0.505506
# Resistivity (Medium)                               -0.461181
# Resistivity (Shallow)                              -0.455882
# Ratio (shallow/deep resistivity)                    0.395101
# Spontaneous Potential                               0.263632
# Micro-inverse resistivity (micro log)              -0.675558
# Micro-normal resistivity (micro log)               -0.748689
# Delta-t (interval transit time, or slowness)        1.000000
# Sonic porosity                                      1.000000

# %%
def display_corr_with_col(df, col):
    correlation_matrix = LogDat_train_new.corr()
    correlation_type = correlation_matrix[col].copy()
    abs_correlation_type = correlation_type.apply(lambda x: abs(x))
    desc_corr_values = abs_correlation_type.sort_values(ascending=False)
    y_values = list(desc_corr_values.values)[1:]
    x_values = range(0,len(y_values))
    xlabels = list(desc_corr_values.keys())[1:]
    fig, ax = plt.subplots(figsize=(10,8))
    ax.bar(x_values, y_values)
    ax.set_title('The correlation of all features with {}'.format(col), fontsize=13)
    ax.set_ylabel('Pearson correlation coefficient [abs waarde]', fontsize=13)
    plt.xticks(x_values, xlabels, rotation='vertical')
    plt.show()

display_corr_with_col(LogDat_train_new, 'Neutron Porosity')

# %%
display_corr_with_col(LogDat_train_new, 'Density Porosity')

# %%
display_corr_with_col(LogDat_train_new, 'Bulk density')

# %%
display_corr_with_col(LogDat_train_new, 'Caliper')

# %%
display_corr_with_col(LogDat_train_new, 'Sonic porosity')

# %%
display_corr_with_col(LogDat_train_new, 'Delta-t (interval transit time, or slowness)')

# %%
display_corr_with_col(LogDat_train_new, 'Micro-normal resistivity (micro log)')

# %%
display_corr_with_col(LogDat_train_new, 'Resistivity (Shallow)')

# %%
display_corr_with_col(LogDat_train_new, 'Ratio (shallow/deep resistivity)')

# %%
display_corr_with_col(LogDat_train_new, 'Gamma ray')

# %%
display_corr_with_col(LogDat_train_new, 'Spontaneous Potential')

# %%
display_corr_with_col(LogDat_train_new, 'Photoelectric')

# %%
display_corr_with_col(LogDat_train_new, 'Resistivity (Medium)')

# %%
display_corr_with_col(LogDat_train_new, 'Density Correction')

# %% [markdown]
# # Training the Data

# %% [raw]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegressionCV

log_reg_n = LogisticRegressionCV(random_state=42)

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(log_reg_n, X_train, y_train_sl, cv=5, scoring ="f1_weighted")
# Out:
# array([0.76907119, 0.73878545, 0.73549518, 0.73614139, 0.72801482])

# %%
y_predLog = log_reg_n.fit(X_train, y_train_sl).predict(X_train)
("Number of mislabeled points out of a total %d points : %d" % (X_train.shape[0],(y_train_sl != y_predLog).sum()))
# Out:
# 'Number of mislabeled points out of a total 1524 points : 335'

# %%
from sklearn.model_selection import cross_val_predict
y_log_crpred =cross_val_predict(log_reg_n, X_train, y_train_sl, cv=5, method ="predict")

# %%
from sklearn.metrics import f1_score

f1_score(y_train_sl, y_log_crpred, average = "weighted")
# Out:
# 0.7416244686585893

# %% [raw]
# RandomForest on training set

# %%
from sklearn.ensemble import RandomForestClassifier

forest_clf_n = RandomForestClassifier(random_state =42)
forest_clf_n.fit(X_train, y_train_sl)
# Out:
# RandomForestClassifier(random_state=42)

# %%
cross_val_score(forest_clf_n, X_train, y_train_sl, cv=5, scoring ="f1_weighted")
# Out:
# array([0.93943642, 0.93231665, 0.96026973, 0.95638253, 0.91486941])

# %%
y_predfor_p_n = forest_clf_n.fit(X_train, y_train_sl).predict(X_train)
("Number of mislabeled points out of a total %d points : %d" % (X_train.shape[0],(y_train_sl != y_predfor_p_n).sum()))
# Out:
# 'Number of mislabeled points out of a total 1524 points : 0'

# %% [markdown]
# ### Decision Tree on training set

# %%
from sklearn.tree import DecisionTreeClassifier
tree_clf_n = DecisionTreeClassifier(random_state =42)
tree_clf_n.fit(X_train, y_train_sl)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
cross_val_score(tree_clf_n, X_train, y_train_sl, cv=5, scoring ="f1_weighted")
# Out:
# array([0.92992549, 0.93098415, 0.94098361, 0.93977313, 0.87557286])

# %%
y_predtree = tree_clf_n.fit(X_train, y_train_sl).predict(X_train)
("Number of mislabeled points out of a total %d points : %d" % (X_train.shape[0],(y_train_sl != y_predtree).sum()))
# Out:
# 'Number of mislabeled points out of a total 1524 points : 0'

# %% [markdown]
# ### GaussuanRBF SVM Classfier on training set

# %%
from sklearn.svm import SVC

rbf_kernel_svm_clf = SVC(C=1, probability = True)
rbf_kernel_svm_clf.fit(X_train, y_train_sl)
# Out:
# SVC(C=1, probability=True)

# %%
cross_val_score(rbf_kernel_svm_clf, X_train, y_train_sl, cv=5, scoring ="f1_weighted")
# Out:
# array([0.88730291, 0.89722573, 0.90636491, 0.90214527, 0.84275744])

# %%
y_predsvm = rbf_kernel_svm_clf.fit(X_train, y_train_sl).predict(X_train)
("Number of mislabeled points out of a total %d points : %d" % (X_train.shape[0],(y_train_sl != y_predsvm).sum()))
# Out:
# 'Number of mislabeled points out of a total 1524 points : 135'

# %%
y_svm_cr = cross_val_predict(rbf_kernel_svm_clf, X_train, y_train_sl, cv =5, method = "predict")

# %%
f1_score(y_train_sl, y_svm_cr, average = 'weighted')
# Out:
# 0.8878357838370131

# %% [markdown]
# ### KNeighborsClassifier on training set

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf_n = KNeighborsClassifier()
knn_clf_n.fit(X_train, y_train_sl)
# Out:
# KNeighborsClassifier()

# %%
cross_val_score(knn_clf_n, X_train, y_train_sl, cv=5, scoring ="f1_weighted")
# Out:
# array([0.88864807, 0.88196721, 0.90209104, 0.91783828, 0.8497162 ])

# %%
y_predknn = knn_clf_n.fit(X_train, y_train_sl).predict(X_train)
("Number of mislabeled points out of a total %d points : %d" % (X_train.shape[0],(y_train_sl != y_predknn).sum()))
# Out:
# 'Number of mislabeled points out of a total 1524 points : 88'

# %% [markdown]
# ### Gaussian Naive Bayes on training set

# %%
from sklearn.naive_bayes import GaussianNB
gnb_clf_n = GaussianNB()
y_predNB = gnb_clf_n.fit(X_train, y_train_sl)

# %%
cross_val_score(gnb_clf_n, X_train, y_train_sl, cv=5, scoring ="f1_weighted")
# Out:
# array([0.73878183, 0.71656672, 0.72471899, 0.74121309, 0.69918881])

# %%
y_predNB_tr = gnb_clf_n.fit(X_train, y_train_sl).predict(X_train)
("Number of mislabeled points out of a total %d points : %d" % (X_train.shape[0],(y_train_sl != y_predNB_tr).sum()))
# Out:
# 'Number of mislabeled points out of a total 1524 points : 440'

# %%
y_predgnb_cv = cross_val_predict(gnb_clf_n, X_train, y_train_sl, cv=5, method = "predict")

# %%
f1_score(y_train_sl, y_predgnb_cv, average = 'weighted')
# Out:
# 0.7243348366027266

# %% [markdown]
# ### Confusion Matrix and Precision and Recall

# %% [markdown]
# #### Random Forest

# %%
from sklearn.model_selection import cross_val_predict

y_train_slpred = cross_val_predict(forest_clf_n, X_train, y_train_sl, cv=5)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_train_sl, y_train_slpred)
# Out:
# array([[1139,   20],
#        [  68,  297]], dtype=int64)

# %%
from sklearn.metrics import precision_score, recall_score

precision_score(y_train_sl, y_train_slpred, average = 'weighted')
# Out:
# 0.9420445106200264

# %%
recall_score(y_train_sl, y_train_slpred,average = 'weighted')
# Out:
# 0.9422572178477691

# %%
from sklearn.metrics import f1_score

f1_score(y_train_sl, y_train_slpred, average = 'weighted')
# Out:
# 0.9408109393846289

# %% [markdown]
# #### Decision Tree Classifier

# %%
y_train_slpred2 = cross_val_predict(tree_clf_n, X_train, y_train_sl, cv=5)

# %%
confusion_matrix(y_train_sl, y_train_slpred2)
# Out:
# array([[1108,   51],
#        [  65,  300]], dtype=int64)

# %%
precision_score(y_train_sl, y_train_slpred2,average = 'weighted')
# Out:
# 0.9230587930066353

# %%
recall_score(y_train_sl, y_train_slpred2,average = 'weighted')
# Out:
# 0.9238845144356955

# %%
f1_score(y_train_sl, y_train_slpred2, average = 'weighted')
# Out:
# 0.9233688456420932

# %% [markdown]
# #### Logistic Regression

# %%
y_train_slpred3 = cross_val_predict(log_reg_n, X_train, y_train_sl, cv=5)

# %%
confusion_matrix(y_train_sl, y_train_slpred3,)
# Out:
# array([[1081,   78],
#        [ 268,   97]], dtype=int64)

# %%
precision_score(y_train_sl, y_train_slpred3,average = 'weighted')
# Out:
# 0.7421658560285599

# %%
recall_score(y_train_sl, y_train_slpred3,average = 'weighted')
# Out:
# 0.7729658792650919

# %%
f1_score(y_train_sl, y_train_slpred3, average = 'weighted')
# Out:
# 0.7416244686585893

# %% [markdown]
# #### K Nearest Neighbor Classifier

# %%
y_train_slpred4 = cross_val_predict(knn_clf_n, X_train, y_train_sl, cv=5)

# %%
confusion_matrix(y_train_sl, y_train_slpred4)
# Out:
# array([[1087,   72],
#        [  96,  269]], dtype=int64)

# %%
precision_score(y_train_sl, y_train_slpred4, average = 'weighted')
# Out:
# 0.8877166287338031

# %%
recall_score(y_train_sl, y_train_slpred4,average = 'weighted')
# Out:
# 0.889763779527559

# %%
f1_score(y_train_sl, y_train_slpred4, average = 'weighted')
# Out:
# 0.8884549072528786

# %% [markdown]
# #### GaussianRBF SVM Classifier

# %%
y_train_slpred5 = cross_val_predict(rbf_kernel_svm_clf, X_train, y_train_sl, cv=5)

# %%
confusion_matrix(y_train_sl, y_train_slpred5)
# Out:
# array([[1104,   55],
#        [ 111,  254]], dtype=int64)

# %%
precision_score(y_train_sl, y_train_slpred5, average = 'weighted')
# Out:
# 0.8878926586891489

# %%
recall_score(y_train_sl, y_train_slpred5, average = 'weighted')
# Out:
# 0.8910761154855643

# %%
f1_score(y_train_sl, y_train_slpred5, average = 'weighted')
# Out:
# 0.8878357838370131

# %% [markdown]
# #### Gaussian Naive Bayes

# %%
y_train_slpred6 = cross_val_predict(gnb_clf_n, X_train, y_train_sl, cv=5)

# %%
confusion_matrix(y_train_sl, y_train_slpred6)
# Out:
# array([[836, 323],
#        [124, 241]], dtype=int64)

# %%
precision_score(y_train_sl, y_train_slpred6, average = 'weighted')
# Out:
# 0.7646077069488655

# %%
recall_score(y_train_sl, y_train_slpred6,average = 'weighted')
# Out:
# 0.7066929133858267

# %%
f1_score(y_train_sl, y_train_slpred6, average = 'weighted')
# Out:
# 0.7243348366027266

# %% [markdown]
# ## ROC Curve

# %%
y_logscores = cross_val_predict(log_reg_n, X_train, y_train_sl, cv=5,
                             method="decision_function")

# %%
y_logscores
# Out:
# array([-0.92284897, -2.00226978, -1.54066359, ..., -1.92381158,
#        -0.82316381, -1.26264723])

# %%
y_logscores.shape
# Out:
# (1524,)

# %%
#hack to work around issue #9589 introduced in Scikit-Learn 0.19.0
if y_logscores.ndim == 2:
    y_logscores = y_logscores[:, 1]

# %%
from sklearn.metrics import precision_recall_curve

precisions, recalls, thresholds = precision_recall_curve(y_train_sl, y_logscores)

# %%
def plot_precision_recall_vs_threshold(precisions, recalls, thresholds):
    plt.plot(thresholds, precisions[:-1], "b--", label="Precision", linewidth=2)
    plt.plot(thresholds, recalls[:-1], "g-", label="Recall", linewidth=2)
    plt.xlabel("Threshold", fontsize=16)
    plt.legend(loc="lower right", fontsize=16)
    plt.ylim([0, 1.1])

plt.figure(figsize=(8, 4))
plot_precision_recall_vs_threshold(precisions, recalls, thresholds)
plt.xlim([-5,5])
plt.show()

# %%
def plot_precision_vs_recall(precisions, recalls):
    plt.plot(recalls, precisions, "b-", linewidth=2)
    plt.xlabel("Recall", fontsize=16)
    plt.ylabel("Precision", fontsize=16)
    plt.axis([0, 1, 0, 1])

plt.figure(figsize=(8, 6))
plot_precision_vs_recall(precisions, recalls)
plt.show()

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_train_sl, y_logscores, average = 'weighted')
# Out:
# 0.7949791388419398

# %%
from sklearn.ensemble import RandomForestClassifier

roc_forest = RandomForestClassifier(random_state = 42)
y_probas_forest = cross_val_predict(roc_forest, X_train, y_train_sl, cv =5, method = "predict_proba")

# %%
from sklearn.metrics import roc_curve

y_scores_forest = y_probas_forest[:,1] #score = proba of positive class
fpr_forest, tpr_forest, thresholds_forest= roc_curve(y_train_sl, y_scores_forest)

# %%
from sklearn.tree import DecisionTreeClassifier

roc_tree= DecisionTreeClassifier(random_state = 42)
y_probas_tree = cross_val_predict(roc_tree, X_train, y_train_sl, cv =5, method = "predict_proba")

# %%
roc_auc_score(y_train_sl, y_scores_forest, average ='weighted') #Best ROC-AUC Score for forest
# Out:
# 0.9820156724620894

# %%
y_scores_tree = y_probas_tree[:,1] #score = proba of positive class
fpr_tree, tpr_tree, thresholds_tree = roc_curve(y_train_sl, y_scores_tree)

# %%
roc_auc_score(y_train_sl, y_scores_tree, average = 'weighted')
# Out:
# 0.8889571784840498

# %%
fpr_log, tpr_log, thresholds_log = roc_curve(y_train_sl, y_logscores)

# %%
y_probas_gnb = cross_val_predict(gnb_clf_n, X_train, y_train_sl, cv =5, method = "predict_proba")

# %%
y_scores_gnb = y_probas_gnb[:,1]
fpr_gnb, tpr_gnb, thresholds_gnb = roc_curve(y_train_sl, y_scores_gnb)

# %%
roc_auc_score(y_train_sl, y_scores_gnb, average = 'weighted')
# Out:
# 0.7359509260463082

# %%
y_probas_knn = cross_val_predict(knn_clf_n, X_train, y_train_sl, cv =5, method = "predict_proba")

# %%
y_scores_knn = y_probas_knn[:,1]
fpr_knn, tpr_knn, thresholds_knn = roc_curve(y_train_sl, y_scores_knn)

# %%
roc_auc_score(y_train_sl, y_scores_knn, average = 'weighted')
# Out:
# 0.9279433143829707

# %%
y_svmscores = cross_val_predict(rbf_kernel_svm_clf, X_train, y_train_sl, cv =5, method = "decision_function")

# %%
#hack to work around issue #9589 introduced in Scikit-Learn 0.19.0
if y_svmscores.ndim == 2:
    y_svmscores = y_svmscores[:, 1]

# %%
fpr_svm, tpr_svm, thresholds_svm = roc_curve(y_train_sl, y_svmscores)

# %%
roc_auc_score(y_train_sl, y_svmscores, average = 'weighted')
# Out:
# 0.9212618341271999

# %% [markdown]
# #### ROC Curve for Random Forest alone

# %%
def plot_roc_curve(fpr, tpr, label=None):
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([0, 1, 0, 1])
    plt.xlabel('False Positive Rate', fontsize=16)
    plt.ylabel('True Positive Rate', fontsize=16)

plt.figure(figsize=(8, 6))
plot_roc_curve(fpr_forest, tpr_forest)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr_log, tpr_log, "b:", linewidth=2, label="Logistic Regressor")
plt.plot(fpr_svm, tpr_svm, "m.", linewidth=1, label="SVM Classifier")
plot_roc_curve(fpr_forest, tpr_forest, "Random Forest")
plot_roc_curve(fpr_tree, tpr_tree, "Decision Tree")
plot_roc_curve(fpr_gnb, tpr_gnb, "Naive Bayes")
plot_roc_curve(fpr_knn, tpr_knn, "K-Nearest Neighbor")
plt.legend(loc="lower right", fontsize=16)
plt.show()

# %% [markdown]
# #### Grid search on three best classifier

# %% [markdown]
# #### KNN on shaly limestone formation

# %%
from sklearn.model_selection import GridSearchCV

weights_sl = ['uniform','distance']
numNeighbors_sl = np.array([3,5,7,9])

# %%
param_grid_knn_sl  = dict(weights=weights_sl,n_neighbors=numNeighbors_sl)

# %%
grid_knn_sl = GridSearchCV(knn_clf_n,param_grid=param_grid_knn_sl,cv=5, n_jobs =-1)

# %%
grid_knn_sl.fit(X_train,y_train_sl)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': array([3, 5, 7, 9]),
#                          'weights': ['uniform', 'distance']})

# %%
grid_knn_sl.best_params_
# Out:
# {'n_neighbors': 9, 'weights': 'distance'}

# %%
grid_knn_sl.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=9, weights='distance')

# %%
knn_clf_sl_GS = KNeighborsClassifier(n_neighbors = 5, weights = 'distance')

# %%
knn_clf_sl_GS.fit(X_train, y_train_sl)
# Out:
# KNeighborsClassifier(weights='distance')

# %%
y_pred_knn_sl  = cross_val_predict(knn_clf_sl_GS, X_train, y_train_sl, cv=5)
f1_score(y_train_sl, y_pred_knn_sl , average="weighted")
# Out:
# 0.8969263746280033

# %%
y_test_knn_pred = knn_clf_sl_GS.predict(X_test_prepared)

# %%
f1_score(y_test_sl, y_test_knn_pred , average="weighted")
# Out:
# 0.9289990817978612

# %%
roc_auc_score(y_test_sl, y_test_knn_pred, average = 'weighted')
# Out:
# 0.9006631299734749

# %% [markdown]
# ### Comparing without grid search

# %%
y_test_knn_noGS = knn_clf_n.predict(X_test_prepared)

# %%
f1_score(y_test_sl, y_test_knn_noGS, average = 'weighted')
# Out:
# 0.9237397545236287

# %%
roc_auc_score(y_test_sl, y_test_knn_noGS, average = 'weighted')
# Out:
# 0.893444486547935

# %% [markdown]
# ### ROC Curve performance prep for KNN on test set

# %%
y_probas_knn_sl = knn_clf_sl_GS.predict_proba(X_test_prepared)

# %%
y_scores_knn_sl = y_probas_knn_sl[:, 1]

# %%
from sklearn.metrics import roc_curve

fpr_knn_sl, tpr_knn_sl, thresholds_knn_sl = roc_curve(y_test_sl, y_scores_knn_sl)

# %% [markdown]
# ### Gaussian RBF SVM Grid search

# %%
Cs = [5, 100, 200]
kernels = ['linear', 'rbf']
decision = ['ovo', 'ovr']

# %%
param_grid_svm_sl  = dict(C=Cs,kernel = kernels, decision_function_shape =decision)

# %%
grid_svm_sl = GridSearchCV(rbf_kernel_svm_clf,param_grid=param_grid_svm_sl,cv=5, n_jobs =-1)

# %%
grid_svm_sl.fit(X_train, y_train_sl)
# Out:
# GridSearchCV(cv=5, estimator=SVC(C=1, probability=True), n_jobs=-1,
#              param_grid={'C': [5, 100, 200],
#                          'decision_function_shape': ['ovo', 'ovr'],
#                          'kernel': ['linear', 'rbf']})

# %%
grid_svm_sl.best_params_
# Out:
# {'C': 200, 'decision_function_shape': 'ovo', 'kernel': 'rbf'}

# %%
grid_svm_sl.best_estimator_
# Out:
# SVC(C=200, decision_function_shape='ovo', probability=True)

# %%
svm_clf_sl_GS = SVC(C= 100, decision_function_shape = 'ovo', random_state =41, probability = True)

# %%
svm_clf_sl_GS.fit(X_train, y_train_sl)
# Out:
# SVC(C=100, decision_function_shape='ovo', probability=True, random_state=41)

# %%
y_pred_svm_sl  = cross_val_predict(svm_clf_sl_GS, X_train, y_train_sl, cv=5, n_jobs=-1)
f1_score(y_train_sl, y_pred_svm_sl , average="weighted")
# Out:
# 0.9290670604171827

# %%
y_test_svm_pred = svm_clf_sl_GS.predict(X_test_prepared)

# %%
f1_score(y_test_sl, y_test_svm_pred , average="weighted")
# Out:
# 0.9583109906960555

# %%
roc_auc_score(y_test_sl, y_test_svm_pred, average = 'weighted')
# Out:
# 0.9497915877226222

# %% [markdown]
# ### Comparing with previous version before Grid search

# %%
rbf_kernel_svm_clf.fit(X_train, y_train_sl)
# Out:
# SVC(C=1, probability=True)

# %%
y_test_svm_noGS = rbf_kernel_svm_clf.predict(X_test_prepared)

# %%
f1_score(y_test_sl, y_test_svm_noGS , average="weighted")
# Out:
# 0.8845593917823233

# %%
roc_auc_score(y_test_sl, y_test_svm_noGS, average = 'weighted')
# Out:
# 0.8240621447518001

# %% [markdown]
# ### ROC Curve preparation for SVM Classifier on Shaly Limestone

# %%
y_probas_svm_sl = rbf_kernel_svm_clf.predict_proba(X_test_prepared)

# %%
y_scores_svm_sl = y_probas_svm_sl[:, 1] # score = proba of positive class
fpr_svm_sl, tpr_svm_sl, thresholds_svm_sl = roc_curve(y_test_sl,y_scores_svm_sl)

# %% [markdown]
# ### Random Forest on shaly limestone grid search

# %%
numEstim_for_sl = [200, 400, 500]
criteria_for_sl = ['gini', 'entropy']

# %%
param_grid_for_sl  = dict(n_estimators = numEstim_for_sl, criterion = criteria_for_sl)

# %%
grid_for_sl = GridSearchCV(forest_clf_n,param_grid=param_grid_for_sl,cv=5, n_jobs =-1)

# %%
grid_for_sl.fit(X_train, y_train_sl)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'n_estimators': [200, 400, 500]})

# %%
grid_for_sl.best_params_
# Out:
# {'criterion': 'entropy', 'n_estimators': 200}

# %%
grid_for_sl.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=200, random_state=42)

# %%
for_clf_sl_GS = RandomForestClassifier(n_estimators = 500, random_state =42)

# %%
for_clf_sl_GS.fit(X_train, y_train_sl)
# Out:
# RandomForestClassifier(n_estimators=500, random_state=42)

# %%
y_pred_for_sl  = cross_val_predict(for_clf_sl_GS, X_train, y_train_sl, cv=5, n_jobs=-1)
f1_score(y_train_sl, y_pred_for_sl , average="weighted")
# Out:
# 0.9410732746801382

# %%
y_test_for_pred = for_clf_sl_GS.predict(X_test_prepared)

# %%
f1_score(y_test_sl, y_test_for_pred , average="weighted")
# Out:
# 0.9461858801831011

# %%
roc_auc_score(y_test_sl, y_test_for_pred, average = 'weighted')
# Out:
# 0.9051913603637741

# %% [markdown]
# ### Comparing without GridSearch

# %%
y_test_for_noGS= forest_clf_n.predict(X_test_prepared)

# %%
f1_score(y_test_sl, y_test_for_noGS, average="weighted")
# Out:
# 0.9461858801831011

# %%
roc_auc_score(y_test_sl, y_test_for_noGS, average = 'weighted')
# Out:
# 0.9051913603637741

# %% [markdown]
# ### ROC Curve preparation of Random Forest on Shaly Limestone

# %%
y_probas_forest_sl = for_clf_sl_GS.predict_proba(X_test_prepared)

# %%
y_scores_forest_sl = y_probas_forest_sl[:, 1] # score = proba of positive class
fpr_forest_sl, tpr_forest_sl, thresholds_forest_sl = roc_curve(y_test_sl,y_scores_forest_sl)

# %% [markdown]
# ### Voting on best classifiers after GridSearch

# %%
from sklearn.ensemble import VotingClassifier

voting_clf_sl = VotingClassifier(estimators = [('svmGS', svm_clf_sl_GS),
                                               ('knnGSsl', knn_clf_sl_GS),
                                               ('rnfGS', for_clf_sl_GS)], voting = 'soft')

# %%
voting_clf_sl.fit(X_train, y_train_sl)
# Out:
# VotingClassifier(estimators=[('svmGS',
#                               SVC(C=100, decision_function_shape='ovo',
#                                   probability=True, random_state=41)),
#                              ('knnGSsl',
#                               KNeighborsClassifier(weights='distance')),
#                              ('rnfGS',
#                               RandomForestClassifier(n_estimators=500,
#                                                      random_state=42))],
#                  voting='soft')

# %%
y_pred_voting_sl  = cross_val_predict(voting_clf_sl, X_train, y_train_sl, cv=5, n_jobs=-1)
f1_score(y_train_sl, y_pred_voting_sl , average="weighted")
# Out:
# 0.9393586519651049

# %%
y_test_voting_pred = voting_clf_sl.predict(X_test_prepared)

# %%
f1_score(y_test_sl, y_test_voting_pred , average="weighted")
# Out:
# 0.9604012996272109

# %%
roc_auc_score(y_test_sl, y_test_voting_pred)
# Out:
# 0.9402046229632436

# %% [markdown]
# ## ROC Curve on Shaly Limestone of three best classifiers on test set

# %%
y_probas_voting_sl = voting_clf_sl.predict_proba(X_test_prepared)

# %%
y_scores_voting_sl = y_probas_voting_sl[:, 1] # score = proba of positive class
fpr_voting_sl, tpr_voting_sl, thresholds_voting_sl = roc_curve(y_test_sl,y_scores_voting_sl)

# %% [markdown]
# ### ROC Curves on Test Set

# %%
plt.figure(figsize=(8, 6))
plot_roc_curve(fpr_voting_sl, tpr_voting_sl, "Voting Classifier")
plot_roc_curve(fpr_forest_sl, tpr_forest_sl, "Random Forest")
plot_roc_curve(fpr_svm_sl, tpr_svm_sl, "Gaussian RBF SVM Classifier")
plot_roc_curve(fpr_knn_sl, tpr_knn_sl, "K-Nearest Neighbor")
plt.legend(loc="lower right", fontsize=16)
plt.title("ROC Curves on Test set of Shaly Limestone")
plt.show()

# %% [markdown]
# ### Grid Search Feature Importance with Shaly Limestone

# %%
feature_importances_for = grid_for_sl.best_estimator_.feature_importances_

# %%
attributes = ["Depth", "Neutron Porosity", "Caliper", "Density Porosity", "Gamma Ray", "Photoelctric",
             "Bulk Density", "Density Correction", "Resistivity (Deep)", "Resistivity (Medium)", "Resistivity (Shallow)",
             "Ratio(Shallow/Deep resistivity)", "SP", "Micro-inverse (resistivity) micro-log", 
              "Micro-normal (resistivity) micro-log", "Delta-t (transit time)", "Sonic Porosity"]
sorted(zip(feature_importances_for*100, attributes), reverse=True)
# Out:
# [(30.090131218816218, 'Depth'),
#  (12.038474065407692, 'Gamma Ray'),
#  (8.239812357706732, 'SP'),
#  (5.438923415017919, 'Density Correction'),
#  (5.288834147085015, 'Resistivity (Deep)'),
#  (4.412546494426873, 'Caliper'),
#  (4.074558187549437, 'Resistivity (Medium)'),
#  (3.868863538912125, 'Sonic Porosity'),
#  (3.793502209026279, 'Delta-t (transit time)'),
#  (3.4275214874015485, 'Photoelctric'),
#  (3.339458531798763, 'Micro-inverse (resistivity) micro-log'),
#  (3.3141816802919744, 'Micro-normal (resistivity) micro-log'),
#  (2.8724805148943244, 'Neutron Porosity'),
#  (2.754762110493775, 'Resistivity (Shallow)'),
#  (2.4818880375201844, 'Density Porosity'),
#  (2.329158196939162, 'Bulk Density'),
#  (2.234903806711994, 'Ratio(Shallow/Deep resistivity)')]

# %% [markdown]
# ### Performance on the rest of the classes

# %%
y_train.head()
# Out:
#       Type of Formation_dolomite  Type of Formation_limestone  \
# 862                            0                            0
# 1416                           0                            1
# 417                            0                            1
# 182                            0                            0
# 1836                           1                            0
#
#       Type of Formation_sandstone  Type of Formation_sandy limestone  \
# 862                             0                                  0
# 1416                            0                                  0
# 417                             0                                  0
# 182                             0                                  0
# 1836                            0                                  0
#
#       Type of Formation_shale  Type of Formation_shaly limestone  \
# 862                         0                                  1
# 1416                        0                                  0
# 417                         0                                  0
# 182                         0                                  1
# 1836                        0                                  0
#
#       Type of Formation_shaly sandstone
# 862                                   0
# 1416                                  0
# 417                                   0
# 182                                   0
# 1836                                  0

# %%
y_train_lim = y_train['Type of Formation_limestone']
y_train_lim.head()
# Out:
# 862     0
# 1416    1
# 417     1
# 182     0
# 1836    0
# Name: Type of Formation_limestone, dtype: uint8

# %%
y_train_sand = y_train['Type of Formation_sandstone']
y_train_sand.head()
# Out:
# 862     0
# 1416    0
# 417     0
# 182     0
# 1836    0
# Name: Type of Formation_sandstone, dtype: uint8

# %%
y_train_dol = y_train['Type of Formation_dolomite']
y_train_dol.head()
# Out:
# 862     0
# 1416    0
# 417     0
# 182     0
# 1836    1
# Name: Type of Formation_dolomite, dtype: uint8

# %%
y_train_lim = y_train['Type of Formation_limestone']
y_train_lim.head()
# Out:
# 862     0
# 1416    1
# 417     1
# 182     0
# 1836    0
# Name: Type of Formation_limestone, dtype: uint8

# %%
y_train_sandlim = y_train['Type of Formation_sandy limestone']
y_train_sandlim.head()
# Out:
# 862     0
# 1416    0
# 417     0
# 182     0
# 1836    0
# Name: Type of Formation_sandy limestone, dtype: uint8

# %%
y_train_shale = y_train['Type of Formation_shale']
y_train_shale.head()
# Out:
# 862     0
# 1416    0
# 417     0
# 182     0
# 1836    0
# Name: Type of Formation_shale, dtype: uint8

# %%
y_train_ss = y_train['Type of Formation_shaly sandstone']
y_train_ss.head()
# Out:
# 862     0
# 1416    0
# 417     0
# 182     0
# 1836    0
# Name: Type of Formation_shaly sandstone, dtype: uint8

# %%
y_test_new.head()
# Out:
#       Type of Formation_dolomite  Type of Formation_limestone  \
# 534                            0                            0
# 1405                           0                            1
# 1821                           1                            0
# 231                            0                            1
# 1045                           0                            1
#
#       Type of Formation_sandstone  Type of Formation_sandy limestone  \
# 534                             0                                  0
# 1405                            0                                  0
# 1821                            0                                  0
# 231                             0                                  0
# 1045                            0                                  0
#
#       Type of Formation_shale  Type of Formation_shaly limestone  \
# 534                         0                                  1
# 1405                        0                                  0
# 1821                        0                                  0
# 231                         0                                  0
# 1045                        0                                  0
#
#       Type of Formation_shaly sandstone
# 534                                   0
# 1405                                  0
# 1821                                  0
# 231                                   0
# 1045                                  0

# %%
y_test_sand = y_test_new['Type of Formation_sandstone']
y_test_sand.head()
# Out:
# 534     0
# 1405    0
# 1821    0
# 231     0
# 1045    0
# Name: Type of Formation_sandstone, dtype: uint8

# %%
y_test_dol = y_test_new['Type of Formation_dolomite']
y_test_dol.head()
# Out:
# 534     0
# 1405    0
# 1821    1
# 231     0
# 1045    0
# Name: Type of Formation_dolomite, dtype: uint8

# %%
y_test_lim = y_test_new['Type of Formation_limestone']
y_test_lim.head()
# Out:
# 534     0
# 1405    1
# 1821    0
# 231     1
# 1045    1
# Name: Type of Formation_limestone, dtype: uint8

# %%
y_test_sandlim = y_test_new['Type of Formation_sandy limestone']
y_test_sandlim.head()
# Out:
# 534     0
# 1405    0
# 1821    0
# 231     0
# 1045    0
# Name: Type of Formation_sandy limestone, dtype: uint8

# %%
y_test_shale = y_test_new['Type of Formation_shale']
y_test_shale.head()
# Out:
# 534     0
# 1405    0
# 1821    0
# 231     0
# 1045    0
# Name: Type of Formation_shale, dtype: uint8

# %%
y_test_ss = y_test_new['Type of Formation_shaly sandstone']
y_test_ss.head()
# Out:
# 534     0
# 1405    0
# 1821    0
# 231     0
# 1045    0
# Name: Type of Formation_shaly sandstone, dtype: uint8

# %% [markdown]
# ### Feature importances on rest of the classes

# %%
y_trains_classes= (y_train_sl, y_train_lim, y_train_shale, y_train_sandlim, 
                   y_train_ss, y_train_dol, y_train_sand)
y_classes_names = ("shaly limestone", "limestone", "shale", "sandy lime", 
                   "shaly sandstone", "dolomite", "sandstone")
y_test_classes = (y_test_sl, y_test_lim, y_test_shale, y_test_sandlim, y_test_ss, y_test_dol, y_test_sand)

# %%
numEstim_for = [200, 400, 500]
criteria_for = ['gini', 'entropy']
param_grid_for  = dict(n_estimators = numEstim_for, criterion = criteria_for)
for_clf_fi = RandomForestClassifier(random_state =42)
attributes_all = ["Depth" ,"Neutron Porosity","Caliper ", "Density Porosity","Gamma Ray",
                      "Photoelectric", "Bulk Density", "Density Correction", "Resistivity (Deep)", 
                       "Resistivity (Medium)", "Resistivity (Shallow)","Ratio(Shallow/Deep resistivity)",
                      "SP",  "Micro-inverse (resistivity) micro-log", "Micro-normal (resistivity) micro-log", 
                    "Delta-t (transit time)", "Sonic Porosity"]

# %% [markdown]
# ### Feature importances of Limestone

# %%
grid_for_lim = GridSearchCV(for_clf_fi,param_grid=param_grid_for,cv=5, n_jobs =-1)
grid_for_lim.fit(X_train, y_train_lim)
feature_importances_lim = grid_for_lim.best_estimator_.feature_importances_
sorted(zip(feature_importances_lim*100, attributes_all), reverse=True)
# Out:
# [(22.072570029260373, 'Depth'),
#  (10.410263882441244, 'Photoelectric'),
#  (7.208865164887894, 'Gamma Ray'),
#  (6.833499258959106, 'SP'),
#  (6.536672438957382, 'Sonic Porosity'),
#  (6.066198611921389, 'Density Correction'),
#  (5.346373941998841, 'Delta-t (transit time)'),
#  (4.4263235004794685, 'Neutron Porosity'),
#  (4.413151152545767, 'Resistivity (Deep)'),
#  (4.1369246219123434, 'Resistivity (Medium)'),
#  (3.5574039354850178, 'Micro-normal (resistivity) micro-log'),
#  (3.478058166608735, 'Density Porosity'),
#  (3.263764872099742, 'Micro-inverse (resistivity) micro-log'),
#  (3.2285393798866586, 'Bulk Density'),
#  (3.0922862030449334, 'Resistivity (Shallow)'),
#  (3.076841393258639, 'Ratio(Shallow/Deep resistivity)'),
#  (2.852263446252473, 'Caliper ')]

# %% [markdown]
# ### Feature importance of Shale

# %%
grid_for_shale = GridSearchCV(for_clf_fi,param_grid=param_grid_for,cv=5, n_jobs =-1)
grid_for_shale.fit(X_train, y_train_shale)
feature_importances_shale = grid_for_shale.best_estimator_.feature_importances_
sorted(zip(feature_importances_shale*100, attributes_all), reverse=True)
# Out:
# [(20.552393374618063, 'Gamma Ray'),
#  (8.961700486459323, 'Depth'),
#  (7.676001120317489, 'SP'),
#  (7.5778678257335335, 'Sonic Porosity'),
#  (6.710698502677752, 'Delta-t (transit time)'),
#  (6.353716072693436, 'Density Correction'),
#  (5.161032337263287, 'Caliper '),
#  (4.9526215509856, 'Resistivity (Deep)'),
#  (4.86326407532208, 'Micro-normal (resistivity) micro-log'),
#  (4.783555269101934, 'Resistivity (Medium)'),
#  (3.9587304774195675, 'Micro-inverse (resistivity) micro-log'),
#  (3.8336040505775806, 'Ratio(Shallow/Deep resistivity)'),
#  (3.341073224690847, 'Resistivity (Shallow)'),
#  (3.150255626349289, 'Neutron Porosity'),
#  (2.921328081355481, 'Photoelectric'),
#  (2.692500882571836, 'Bulk Density'),
#  (2.5096570418629036, 'Density Porosity')]

# %% [markdown]
# ### Feature importance of Shaly-Limestone

# %%
grid_for_sandlim = GridSearchCV(for_clf_fi,param_grid=param_grid_for,cv=5, n_jobs =-1)
grid_for_sandlim.fit(X_train, y_train_sandlim)
feature_importances_sandlim = grid_for_sandlim.best_estimator_.feature_importances_
sorted(zip(feature_importances_sandlim*100, attributes_all), reverse=True)
# Out:
# [(14.812044475593614, 'Resistivity (Shallow)'),
#  (12.896914565842286, 'Density Porosity'),
#  (11.237188149780929, 'Resistivity (Medium)'),
#  (11.195047085161884, 'Bulk Density'),
#  (10.14063603079975, 'Resistivity (Deep)'),
#  (8.701526660433636, 'Neutron Porosity'),
#  (5.640571125497912, 'Sonic Porosity'),
#  (4.989550412912183, 'Micro-normal (resistivity) micro-log'),
#  (4.150949615502878, 'Delta-t (transit time)'),
#  (3.1717520456268495, 'Micro-inverse (resistivity) micro-log'),
#  (3.1443573220457495, 'Depth'),
#  (2.8935010354619153, 'SP'),
#  (2.112589157606421, 'Photoelectric'),
#  (1.8104807060525772, 'Ratio(Shallow/Deep resistivity)'),
#  (1.4558839698793693, 'Gamma Ray'),
#  (1.0881094072861974, 'Density Correction'),
#  (0.5588982345158489, 'Caliper ')]

# %% [markdown]
# ### Feature importances of Shaly Sandstone

# %%
grid_for_ss = GridSearchCV(for_clf_fi,param_grid=param_grid_for,cv=4, n_jobs =-1)
grid_for_ss.fit(X_train, y_train_ss)
feature_importances_ss = grid_for_ss.best_estimator_.feature_importances_
sorted(zip(feature_importances_ss*100, attributes_all), reverse=True)
# Out:
# [(16.146766863841236, 'Depth'),
#  (13.003256802651194, 'SP'),
#  (8.537432303316567, 'Neutron Porosity'),
#  (8.390372351019906, 'Gamma Ray'),
#  (7.7843985105685185, 'Photoelectric'),
#  (6.855407265275551, 'Density Correction'),
#  (6.1931572066078155, 'Density Porosity'),
#  (5.447464325945742, 'Caliper '),
#  (4.8972916992575115, 'Micro-inverse (resistivity) micro-log'),
#  (4.862049731201055, 'Bulk Density'),
#  (3.2419953903702607, 'Micro-normal (resistivity) micro-log'),
#  (3.2372041804536273, 'Resistivity (Deep)'),
#  (2.9493491886698346, 'Resistivity (Medium)'),
#  (2.5317703641281897, 'Ratio(Shallow/Deep resistivity)'),
#  (2.0638536661588236, 'Sonic Porosity'),
#  (1.9763729389792113, 'Delta-t (transit time)'),
#  (1.8818572115549554, 'Resistivity (Shallow)')]

# %% [markdown]
# ### Feature importances of Dolomite

# %%
grid_for_dol = GridSearchCV(for_clf_fi,param_grid=param_grid_for,cv=5, n_jobs =-1)
grid_for_dol.fit(X_train, y_train_dol)
feature_importances_dol = grid_for_dol.best_estimator_.feature_importances_
sorted(zip(feature_importances_dol*100, attributes_all), reverse=True)
# Out:
# [(54.44688609115019, 'Depth'),
#  (9.961261594295866, 'Caliper '),
#  (6.662687468950653, 'SP'),
#  (6.494628152582202, 'Gamma Ray'),
#  (4.63771561702913, 'Photoelectric'),
#  (3.33150177390322, 'Neutron Porosity'),
#  (2.469458387718418, 'Ratio(Shallow/Deep resistivity)'),
#  (1.940143817515547, 'Density Porosity'),
#  (1.8849134795729199, 'Resistivity (Deep)'),
#  (1.8669571601543502, 'Bulk Density'),
#  (1.4554163721457312, 'Resistivity (Medium)'),
#  (1.050255195658963, 'Delta-t (transit time)'),
#  (0.9895576294286766, 'Density Correction'),
#  (0.8683000044244127, 'Sonic Porosity'),
#  (0.8261834101323591, 'Resistivity (Shallow)'),
#  (0.6406095918867186, 'Micro-normal (resistivity) micro-log'),
#  (0.47352425345062904, 'Micro-inverse (resistivity) micro-log')]

# %% [markdown]
# ### Feature importance of Sandstone

# %%
grid_for_sand = GridSearchCV(for_clf_fi,param_grid=param_grid_for,cv=5, n_jobs =-1)
grid_for_sand.fit(X_train, y_train_sand)
feature_importances_sand = grid_for_sand.best_estimator_.feature_importances_
sorted(zip(feature_importances_sand*100, attributes_all), reverse=True)
# Out:
# [(35.48711770601092, 'Photoelectric'),
#  (18.24975554252185, 'Depth'),
#  (11.460466419358976, 'Gamma Ray'),
#  (7.084267193439159, 'Bulk Density'),
#  (6.027188379397149, 'Density Porosity'),
#  (4.97541220965169, 'Neutron Porosity'),
#  (2.286592131752139, 'Caliper '),
#  (1.8713807374466822, 'SP'),
#  (1.8274765189266602, 'Sonic Porosity'),
#  (1.775583132119387, 'Delta-t (transit time)'),
#  (1.5163635731029137, 'Density Correction'),
#  (1.4125915838011565, 'Resistivity (Medium)'),
#  (1.3194938176649815, 'Ratio(Shallow/Deep resistivity)'),
#  (1.2918054809659882, 'Resistivity (Shallow)'),
#  (1.2058932393943538, 'Micro-inverse (resistivity) micro-log'),
#  (1.1382289846285287, 'Resistivity (Deep)'),
#  (1.0703833498174784, 'Micro-normal (resistivity) micro-log')]

# %% [markdown]
# ### Automation for training all classes with all classifiers applied uptil now

# %%
from sklearn.svm import SVC

svm_clf_GS = SVC(C= 100, decision_function_shape = 'ovo', random_state =41, probability = True)

for y_train_all, y_test_all, y_strings_all in zip(y_trains_classes, 
                                                    y_test_classes, y_classes_names):
    svm_clf_GS.fit(X_train, y_train_all)
    y_cv_svm = cross_val_score(svm_clf_GS, X_train, y_train_all, cv = 4)
    print("\n","cross-validation score on training set for", y_strings_all, "with SVMClassifier =", y_cv_svm )
    
    y_cvp_svm = cross_val_predict(svm_clf_GS, X_train, y_train_all, cv=4)
    f1_cvp_train_svm = f1_score(y_train_all, y_cvp_svm, average = 'weighted', labels = np.unique(y_cvp_svm))
    print("f1 scores of cross validation prediction training set for", y_strings_all, "with SVMClassifier =", f1_cvp_train_svm)
    roc_auc_score_svm_train = roc_auc_score(y_train_all, y_cvp_svm, average = 'weighted')
    print("roc auc score on cross validation prediction training set for", 
          y_strings_all,"with SVMClassifier =", roc_auc_score_svm_train)


    y_cvp_svm_test = svm_clf_GS.predict(X_test_prepared)
    f1_svm_test_all = f1_score(y_test_all, y_cvp_svm_test, average = 'weighted', labels = np.unique(y_cvp_svm_test))
    print("f1 score of actual prediction on test set of", y_strings_all, 
          "with SVMClassifier =", f1_svm_test_all)
    roc_auc_score_svm_test_all = roc_auc_score(y_test_all, y_cvp_svm_test, average = 'weighted')
    print("roc auc score of actual prediction on test set of",y_strings_all, "with SVMClassifier =",
          roc_auc_score_svm_test_all)
# Out:
#  cross-validation score on training set for shaly limestone with SVMClassifier = [0.9343832  0.92913386 0.94225722 0.89238845]
# f1 scores of cross validation prediction training set for shaly limestone with SVMClassifier = 0.9247157867541894
# roc auc score on cross validation prediction training set for shaly limestone with SVMClassifier = 0.8987731511577056
# f1 score of actual prediction on test set of shaly limestone with SVMClassifier = 0.9583109906960555
# roc auc score of actual prediction on test set of shaly limestone with SVMClassifier = 0.9497915877226222
#
#  cross-validation score on training set for limestone with SVMClassifier = [0.93175853 0.92388451 0.94750656 0.90026247]
# f1 scores of cross validation prediction training set for limestone with SVMClassifier = 0.9258531779950657
# roc auc score on cross validation prediction training set for limestone with SVMClassifier = 0.9258647859670878
# f1 score of actual prediction on test set of limestone with SVMClassifier = 0.937007874015748
# roc auc score of actual prediction on test set of limestone with SVMClassifier = 0.937007440066134
#
#  cross-validation score on training set for shale with SVMClassifier = [0.93963255 0.94750656 0.94225722 0.93175853]
# f1 scores of cross validation prediction training set for shale with SVMClassifier = 0.9397235507766543
# roc auc score on cross validation prediction training set for shale with SVMClassifier = 0.863086907199788
# f1 score of actual prediction on test set of shale with SVMClassifier = 0.9335575986750403
# roc auc score of actual prediction on test set of shale with SVMClassifier = 0.8486672901566519
#
#  cross-validation score on training set for sandy lime with SVMClassifier = [0.99737533 0.99737533 1.         1.        ]
# f1 scores of cross validation prediction training set for sandy lime with SVMClassifier = 0.9986654764683075
# roc auc score on cross validation prediction training set for sandy lime with SVMClassifier = 0.9666666666666667
# f1 score of actual prediction on test set of sandy lime with SVMClassifier = 0.9974507627920375
# roc auc score of actual prediction on test set of sandy lime with SVMClassifier = 0.9986595174262735
#
#  cross-validation score on training set for shaly sandstone with SVMClassifier = [1. 1. 1. 1.]
# f1 scores of cross validation prediction training set for shaly sandstone with SVMClassifier = 1.0
# roc auc score on cross validation prediction training set for shaly sandstone with SVMClassifier = 1.0
# f1 score of actual prediction on test set of shaly sandstone with SVMClassifier = 0.9986859395532194
# roc auc score of actual prediction on test set of shaly sandstone with SVMClassifier = 0.5
#
#  cross-validation score on training set for dolomite with SVMClassifier = [1.         1.         1.         0.99737533]
# f1 scores of cross validation prediction training set for dolomite with SVMClassifier = 0.9993423927652647
# roc auc score on cross validation prediction training set for dolomite with SVMClassifier = 0.9952830188679245
# f1 score of actual prediction on test set of dolomite with SVMClassifier = 1.0
# roc auc score of actual prediction on test set of dolomite with SVMClassifier = 1.0
#
#  cross-validation score on training set for sandstone with SVMClassifier = [0.99212598 1.         0.99475066 0.99212598]
# f1 scores of cross validation prediction training set for sandstone with SVMClassifier = 0.9948542267567643
# roc auc score on cross validation prediction training set for sandstone with SVMClassifier = 0.9766922600440802
# f1 score of actual prediction on test set of sandstone with SVMClassifier = 1.0
# roc auc score of actual prediction on test set of sandstone with SVMClassifier = 1.0

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_clf_GS = KNeighborsClassifier(n_neighbors = 5, weights = 'distance')

for y_train_all, y_test_all, y_strings_all in zip(y_trains_classes, 
                                                  y_test_classes, y_classes_names):
    knn_clf_GS.fit(X_train, y_train_all)
    y_cv_knn = cross_val_score(knn_clf_GS, X_train, y_train_all, cv = 4)
    print("\n","cross-validation score on training set for", y_strings_all, "with KNeighbor Classifier =", y_cv_knn)
    
    y_cvp_knn = cross_val_predict(knn_clf_GS, X_train, y_train_all, cv=4)
    f1_cvp_train_knn = f1_score(y_train_all, y_cvp_knn, average = 'weighted', labels = np.unique(y_cvp_knn))
    print("f1 scores of cross validation prediction training set for", y_strings_all, 
          "with KNeighbor Classifier =", f1_cvp_train_knn)
    roc_auc_score_knn_train = roc_auc_score(y_train_all, y_cvp_knn, average = 'weighted')
    print("roc auc score on cross validation prediction training set for", 
          y_strings_all,"with KNeighbors Classifier =", roc_auc_score_knn_train)


    y_cvp_knn_test = knn_clf_GS.predict(X_test_prepared)
    f1_knn_test_all = f1_score(y_test_all, y_cvp_knn_test, average = 'weighted', labels = np.unique(y_cvp_knn_test))
    print("f1 score of actual prediction on test set of", y_strings_all, 
          "with KNeighbors Classifier =", f1_knn_test_all)
    roc_auc_score_knn_test_all = roc_auc_score(y_test_all, y_cvp_knn_test, average = 'weighted')
    print("roc auc score of actual prediction on test set of",y_strings_all, "with KNeighbors Classifier =",
          roc_auc_score_knn_test_all)
# Out:
#  cross-validation score on training set for shaly limestone with KNeighbor Classifier = [0.89501312 0.90551181 0.90288714 0.87139108]
# f1 scores of cross validation prediction training set for shaly limestone with KNeighbor Classifier = 0.892215211737132
# roc auc score on cross validation prediction training set for shaly limestone with KNeighbors Classifier = 0.8409587859160589
# f1 score of actual prediction on test set of shaly limestone with KNeighbors Classifier = 0.9289990817978612
# roc auc score of actual prediction on test set of shaly limestone with KNeighbors Classifier = 0.9006631299734749
#
#  cross-validation score on training set for limestone with KNeighbor Classifier = [0.8976378  0.90551181 0.89501312 0.88713911]
# f1 scores of cross validation prediction training set for limestone with KNeighbor Classifier = 0.8962979531856577
# roc auc score on cross validation prediction training set for limestone with KNeighbors Classifier = 0.8962670180061484
# f1 score of actual prediction on test set of limestone with KNeighbors Classifier = 0.9291338582677166
# roc auc score of actual prediction on test set of limestone with KNeighbors Classifier = 0.9291402590245247
#
#  cross-validation score on training set for shale with KNeighbor Classifier = [0.91338583 0.93700787 0.9160105  0.90551181]
# f1 scores of cross validation prediction training set for shale with KNeighbor Classifier = 0.912963666222643
# roc auc score on cross validation prediction training set for shale with KNeighbors Classifier = 0.7723713481739028
# f1 score of actual prediction on test set of shale with KNeighbors Classifier = 0.912685324154672
# roc auc score of actual prediction on test set of shale with KNeighbors Classifier = 0.7666880991349077
#
#  cross-validation score on training set for sandy lime with KNeighbor Classifier = [0.99475066 0.99737533 1.         1.        ]
# f1 scores of cross validation prediction training set for sandy lime with KNeighbor Classifier = 0.9979806805414172
# roc auc score on cross validation prediction training set for sandy lime with KNeighbors Classifier = 0.95
# f1 score of actual prediction on test set of sandy lime with KNeighbors Classifier = 1.0
# roc auc score of actual prediction on test set of sandy lime with KNeighbors Classifier = 1.0
#
#  cross-validation score on training set for shaly sandstone with KNeighbor Classifier = [0.99737533 1.         0.99737533 0.99737533]
# f1 scores of cross validation prediction training set for shaly sandstone with KNeighbor Classifier = 0.9979224586067907
# roc auc score on cross validation prediction training set for shaly sandstone with KNeighbors Classifier = 0.799670836076366
# f1 score of actual prediction on test set of shaly sandstone with KNeighbors Classifier = 0.9986859395532194
# roc auc score of actual prediction on test set of shaly sandstone with KNeighbors Classifier = 0.5
#
#  cross-validation score on training set for dolomite with KNeighbor Classifier = [1.         1.         0.99737533 0.99737533]
# f1 scores of cross validation prediction training set for dolomite with KNeighbor Classifier = 0.9986876640419947
# roc auc score on cross validation prediction training set for dolomite with KNeighbors Classifier = 0.9949304095590387
# f1 score of actual prediction on test set of dolomite with KNeighbors Classifier = 1.0
# roc auc score of actual prediction on test set of dolomite with KNeighbors Classifier = 1.0
#
#  cross-validation score on training set for sandstone with KNeighbor Classifier = [0.99475066 1.         0.99737533 1.        ]
# f1 scores of cross validation prediction training set for sandstone with KNeighbor Classifier = 0.998041523304249
# roc auc score on cross validation prediction training set for sandstone with KNeighbors Classifier = 0.9886846540572465
# f1 score of actual prediction on test set of sandstone with KNeighbors Classifier = 1.0
# roc auc score of actual prediction on test set of sandstone with KNeighbors Classifier = 1.0

# %%
from sklearn.ensemble import RandomForestClassifier

for_clf_GS = RandomForestClassifier(n_estimators = 500, random_state =42)

for y_train_all, y_test_all, y_strings_all in zip(y_trains_classes, 
                                                     y_test_classes, y_classes_names):
    for_clf_GS.fit(X_train, y_train_all)
    y_cv_randfor = cross_val_score(for_clf_GS, X_train, y_train_all, cv = 4)
    print("\n","cross-validation score on training set for", y_strings_all, "with RandomForestClassifier =", y_cv_randfor )
    
    y_cvp_randfor = cross_val_predict(for_clf_GS, X_train, y_train_all, cv=4)
    f1_cvp_train = f1_score(y_train_all, y_cvp_randfor, average = 'weighted', labels = np.unique(y_cvp_randfor))
    print("f1 scores of cross validation prediction training set for", y_strings_all, "=", f1_cvp_train)
    roc_auc_score_randfor_train = roc_auc_score(y_train_all, y_cvp_randfor, average = 'weighted')
    print("roc auc score on cross validation prediction training set for", 
          y_strings_all,"with RandomForestClassifier =", roc_auc_score_randfor_train)


    y_cvp_randfor_test = for_clf_GS.predict(X_test_prepared)
    f1_for_test_all = f1_score(y_test_all, y_cvp_randfor_test, average = 'weighted', labels = np.unique(y_cvp_randfor_test))
    print("f1 score of actual prediction on test set of", y_strings_all, 
          "with RandomForestClassifier =", f1_for_test_all)
    roc_auc_score_randfor_test_all = roc_auc_score(y_test_all, y_cvp_randfor_test, average = 'weighted')
    print("roc auc score of actual prediction on test set of",y_strings_all, "with RandomForestClassifier =",
          roc_auc_score_randfor_test_all)
# Out:
#  cross-validation score on training set for shaly limestone with RandomForestClassifier = [0.94488189 0.94488189 0.95800525 0.92125984]
# f1 scores of cross validation prediction training set for shaly limestone = 0.9409432328968349
# roc auc score on cross validation prediction training set for shaly limestone with RandomForestClassifier = 0.9000981006299715
# f1 score of actual prediction on test set of shaly limestone with RandomForestClassifier = 0.9461858801831011
# roc auc score of actual prediction on test set of shaly limestone with RandomForestClassifier = 0.9051913603637741
#
#  cross-validation score on training set for limestone with RandomForestClassifier = [0.91338583 0.92125984 0.93175853 0.9160105 ]
# f1 scores of cross validation prediction training set for limestone = 0.9206027515243627
# roc auc score on cross validation prediction training set for limestone with RandomForestClassifier = 0.9205946937404739
# f1 score of actual prediction on test set of limestone with RandomForestClassifier = 0.9580035134497077
# roc auc score of actual prediction on test set of limestone with RandomForestClassifier = 0.9579911821438413
#
#  cross-validation score on training set for shale with RandomForestClassifier = [0.9343832  0.93963255 0.93175853 0.9343832 ]
# f1 scores of cross validation prediction training set for shale = 0.9297368052349732
# roc auc score on cross validation prediction training set for shale with RandomForestClassifier = 0.7945217083842834
# f1 score of actual prediction on test set of shale with RandomForestClassifier = 0.9352181437276599
# roc auc score of actual prediction on test set of shale with RandomForestClassifier = 0.8112286649520692
#
#  cross-validation score on training set for sandy lime with RandomForestClassifier = [0.99212598 0.99475066 1.         1.        ]
# f1 scores of cross validation prediction training set for sandy lime = 0.9965727714464266
# roc auc score on cross validation prediction training set for sandy lime with RandomForestClassifier = 0.9166666666666667
# f1 score of actual prediction on test set of sandy lime with RandomForestClassifier = 1.0
# roc auc score of actual prediction on test set of sandy lime with RandomForestClassifier = 1.0
#
#  cross-validation score on training set for shaly sandstone with RandomForestClassifier = [0.99737533 1.         1.         0.99475066]
# f1 scores of cross validation prediction training set for shaly sandstone = 0.9976106447726589
# roc auc score on cross validation prediction training set for shaly sandstone with RandomForestClassifier = 0.7
# f1 score of actual prediction on test set of shaly sandstone with RandomForestClassifier = 0.9986859395532194
# roc auc score of actual prediction on test set of shaly sandstone with RandomForestClassifier = 0.5
#
#  cross-validation score on training set for dolomite with RandomForestClassifier = [1.         1.         0.99737533 0.99475066]
# f1 scores of cross validation prediction training set for dolomite = 0.9980271782957938
# roc auc score on cross validation prediction training set for dolomite with RandomForestClassifier = 0.9902134284269632
# f1 score of actual prediction on test set of dolomite with RandomForestClassifier = 1.0
# roc auc score of actual prediction on test set of dolomite with RandomForestClassifier = 1.0
#
#  cross-validation score on training set for sandstone with RandomForestClassifier = [0.99737533 1.         0.99475066 1.        ]
# f1 scores of cross validation prediction training set for sandstone = 0.9980212457886846
# roc auc score on cross validation prediction training set for sandstone with RandomForestClassifier = 0.9783848802201127
# f1 score of actual prediction on test set of sandstone with RandomForestClassifier = 1.0
# roc auc score of actual prediction on test set of sandstone with RandomForestClassifier = 1.0

# %%
from sklearn.ensemble import VotingClassifier

voting_clf_all = VotingClassifier(estimators = [('knnGS', knn_clf_GS),
                                                ('svmGS', svm_clf_GS),
                                               ('rnfGS', for_clf_GS)], voting = 'soft')

for y_train_all, y_test_all, y_strings_all in zip(y_trains_classes, 
                                                     y_test_classes, y_classes_names):

    voting_clf_all.fit(X_train, y_train_all)
    y_cv_voting = cross_val_score(voting_clf_all, X_train, y_train_all, cv = 4)
    print("\n","cross-validation score on training set for", y_strings_all,
          "with Voting b/w three classifier =", y_cv_voting )
    
    y_pred_voting  = cross_val_predict(voting_clf_all, X_train, y_train_all, cv=4, n_jobs=-1)
    f1_cvp_train_voting = f1_score(y_train_all, y_pred_voting , average="weighted", labels = np.unique(y_pred_voting))
    print("f1 scores of cross validation prediction training set for", y_strings_all, 
          "with Voting b/w three classifier =", f1_cvp_train_voting)
    roc_auc_score_voting_train = roc_auc_score(y_train_all, y_pred_voting, average = 'weighted')
    print("roc auc score on cross validation prediction training set for"
          , y_strings_all,"with Voting b/w three classifier =", roc_auc_score_voting_train)

    y_test_voting_pred_all = voting_clf_all.predict(X_test_prepared)
    f1_test_voting_all = f1_score(y_test_all, y_test_voting_pred_all, 
                                  average= 'weighted', labels = np.unique(y_test_voting_pred_all))
    print("f1 score of actual prediction on test set of", y_strings_all, 
          "with Voting b/w three classifier =", f1_test_voting_all)
    roc_auc_score_voting_test_all = roc_auc_score(y_test_all, y_test_voting_pred_all, average= 'weighted')
    print("roc auc score of actual prediction on test set of",y_strings_all, 
          "with Voting b/w three classifier =", roc_auc_score_voting_test_all)
# Out:
#  cross-validation score on training set for shaly limestone with Voting b/w three classifier = [0.93175853 0.93963255 0.94750656 0.92388451]
# f1 scores of cross validation prediction training set for shaly limestone with Voting b/w three classifier = 0.934589668748303
# roc auc score on cross validation prediction training set for shaly limestone with Voting b/w three classifier = 0.8957840367818266
# f1 score of actual prediction on test set of shaly limestone with Voting b/w three classifier = 0.9604012996272109
# roc auc score of actual prediction on test set of shaly limestone with Voting b/w three classifier = 0.9402046229632436
#
#  cross-validation score on training set for limestone with Voting b/w three classifier = [0.9343832  0.93175853 0.94225722 0.91338583]
# f1 scores of cross validation prediction training set for limestone with Voting b/w three classifier = 0.9304449963006491
# roc auc score on cross validation prediction training set for limestone with Voting b/w three classifier = 0.9304347826086957
# f1 score of actual prediction on test set of limestone with Voting b/w three classifier = 0.9553805774278216
# roc auc score of actual prediction on test set of limestone with Voting b/w three classifier = 0.9553871589969688
#
#  cross-validation score on training set for shale with Voting b/w three classifier = [0.93175853 0.94225722 0.93175853 0.93175853]
# f1 scores of cross validation prediction training set for shale with Voting b/w three classifier = 0.9295210186162661
# roc auc score on cross validation prediction training set for shale with Voting b/w three classifier = 0.7982379893041825
# f1 score of actual prediction on test set of shale with Voting b/w three classifier = 0.9420753550027279
# roc auc score of actual prediction on test set of shale with Voting b/w three classifier = 0.8385550619593173
#
#  cross-validation score on training set for sandy lime with Voting b/w three classifier = [0.99475066 0.99737533 1.         1.        ]
# f1 scores of cross validation prediction training set for sandy lime with Voting b/w three classifier = 0.9979806805414172
# roc auc score on cross validation prediction training set for sandy lime with Voting b/w three classifier = 0.95
# f1 score of actual prediction on test set of sandy lime with Voting b/w three classifier = 1.0
# roc auc score of actual prediction on test set of sandy lime with Voting b/w three classifier = 1.0
#
#  cross-validation score on training set for shaly sandstone with Voting b/w three classifier = [0.99737533 1.         1.         0.99475066]
# f1 scores of cross validation prediction training set for shaly sandstone with Voting b/w three classifier = 0.9976106447726589
# roc auc score on cross validation prediction training set for shaly sandstone with Voting b/w three classifier = 0.7
# f1 score of actual prediction on test set of shaly sandstone with Voting b/w three classifier = 0.9986859395532194
# roc auc score of actual prediction on test set of shaly sandstone with Voting b/w three classifier = 0.5
#
#  cross-validation score on training set for dolomite with Voting b/w three classifier = [1.         1.         1.         0.99737533]
# f1 scores of cross validation prediction training set for dolomite with Voting b/w three classifier = 0.9993423927652647
# roc auc score on cross validation prediction training set for dolomite with Voting b/w three classifier = 0.9952830188679245
# f1 score of actual prediction on test set of dolomite with Voting b/w three classifier = 1.0
# roc auc score of actual prediction on test set of dolomite with Voting b/w three classifier = 1.0
#
#  cross-validation score on training set for sandstone with Voting b/w three classifier = [0.99737533 1.         0.99475066 0.99737533]
# f1 scores of cross validation prediction training set for sandstone with Voting b/w three classifier = 0.9973753280839895
# roc auc score on cross validation prediction training set for sandstone with Voting b/w three classifier = 0.9780463561849061
# f1 score of actual prediction on test set of sandstone with Voting b/w three classifier = 1.0
# roc auc score of actual prediction on test set of sandstone with Voting b/w three classifier = 1.0

# %% [markdown]
# ### ROC performance on training sets of all classes

# %%
for y_train_all, y_test_all, y_strings_all in zip(y_trains_classes, 
                                                    y_test_classes, y_classes_names):
    #ROC-curves of SVM
    y_svm_proba_train = cross_val_predict(svm_clf_GS, X_train, y_train_all, cv=4,
                             method="predict_proba")
    y_svm_scores_train = y_svm_proba_train[:, 1]

    fpr_svm_train, tpr_svm_train, thresholds_svm_train = roc_curve(
                                                                    y_train_all, 
                                                                    y_svm_scores_train)
    

    #ROC-curves for KNN
    y_knn_proba_train = cross_val_predict(knn_clf_GS, X_train, y_train_all, cv=4,
                             method="predict_proba")
    y_knn_scores_train = y_knn_proba_train[:, 1]

    fpr_knn_train, tpr_knn_train, thresholds_knn_train = roc_curve(
                                                                    y_train_all, 
                                                                    y_knn_scores_train)
    
    
    #ROC-curves for RandomForestClf
    y_randfor_proba_train = cross_val_predict(for_clf_GS, X_train, y_train_all, cv=4,
                             method="predict_proba")
    y_randfor_scores_train = y_randfor_proba_train[:, 1]

    fpr_randfor_train, tpr_randfor_train, thresholds_randfor_trainr = roc_curve(
                                                                                y_train_all, 
                                                                                y_randfor_scores_train)
    
    
    #ROC-curves for voting

    y_voting_proba_train_all = cross_val_predict(voting_clf_all, X_train, y_train_all, cv=4,
                             method="predict_proba")
    y_voting_scores_train_all = y_voting_proba_train_all[:, 1]
    fpr_voting_train_all, tpr_voting_train_all, thresholds_voting_train_all = roc_curve(y_train_all, 
                                                                                 y_voting_scores_train_all)
    
    #Plotting ROC-curves for each class
    plt.figure(figsize=(8, 6))
    plot_roc_curve(fpr_svm_train, tpr_svm_train, "SVM Classifier")
    plot_roc_curve(fpr_knn_train, tpr_knn_train, "K-Nearest Neighbor")
    plot_roc_curve(fpr_randfor_train, tpr_randfor_train, "Random Forest")
    plot_roc_curve(fpr_voting_train_all, tpr_voting_train_all, "Voting Classifier")
    plt.legend(loc="lower right", fontsize=16)
    plt.title('ROC curve on training set of  %s'%(y_strings_all))
    plt.axis([-0.01, 1.01, -0.01, 1.01])
    plt.show()

# %% [markdown]
# ### ROC performance on all classes of test sets

# %%
for y_train_all, y_test_all, y_strings_all in zip(y_trains_classes, 
                                                    y_test_classes, y_classes_names):    
    
    svm_clf_GS.fit(X_train, y_train_all)
    y_svm_proba_test = svm_clf_GS.predict_proba(X_test_prepared)
    y_svm_scores_test = y_svm_proba_test[:, 1]

    fpr_svm_test, tpr_svm_test, thresholds_svm_test = roc_curve(y_test_all, 
                                                                y_svm_scores_test)
    
    knn_clf_GS.fit(X_train, y_train_all)
    y_knn_proba_test = knn_clf_GS.predict_proba(X_test_prepared)
    y_knn_scores_test = y_knn_proba_test[:, 1]

    fpr_knn_test, tpr_knn_test, thresholds_knn_test = roc_curve(y_test_all, 
                                                                y_knn_scores_test)
    
    for_clf_GS.fit(X_train, y_train_all)
    y_randfor_proba_test = for_clf_GS.predict_proba(X_test_prepared)
    y_randfor_scores_test = y_randfor_proba_test[:, 1]

    fpr_randfor_test, tpr_randfor_test, thresholds_randfor_test = roc_curve(y_test_all, 
                                                                            y_randfor_scores_test)
    
    voting_clf_all.fit(X_train, y_train_all)
    y_probas_voting_all = voting_clf_all.predict_proba(X_test_prepared)
    y_scores_voting_all = y_probas_voting_all[:, 1] # score = proba of positive class
    fpr_voting_test_all, tpr_voting_test_all, thresholds_voting_test_all = roc_curve(y_test_all,
                                                                              y_scores_voting_all)
    
    plt.figure(figsize=(8, 6))
    plot_roc_curve(fpr_svm_test, tpr_svm_test, "SVM Classifier")
    plot_roc_curve(fpr_knn_test, tpr_knn_test, "K-Nearest Neighbor")
    plot_roc_curve(fpr_randfor_test, tpr_randfor_test, "Random Forest")
    plot_roc_curve(fpr_voting_test_all, tpr_voting_test_all, "Voting Classifier")
    plt.legend(loc="lower right", fontsize=16)
    plt.title('ROC curve on test of  %s'%(y_strings_all))
    plt.axis([-0.01, 1.01, -0.01, 1.01])
    plt.show()

# %% [markdown]
# ### Manual Voting on Shaly Limestone

# %%
# parameters for random forest
rfclf_params_sl = {
    'n_estimators': 500, 
    'bootstrap': True, 
    'class_weight':None, 
    'criterion':'gini',
    'max_depth':None, 
    'max_features':'auto',
    'random_state' : 41
    
    # ... fill in the rest you want here
}

# Fill in svm params here
svm_params_sl = {
    'C': 100,
    'probability':True,
    'random_state' : 42
}

# KNeighbors params go here
kneighbors_params_sl= {
    'n_neighbors': 5,
    'weights':'distance'
}

params_sl = [rfclf_params_sl, svm_params_sl, kneighbors_params_sl]
classifiers_sl = [RandomForestClassifier, SVC, KNeighborsClassifier]

# %%
def ensemble_test(classifiers, params, X_train, y_train, X_test):
    best_preds_test = np.zeros((len(X_test), 2))
    classes_test = np.unique(y_train)

    for i in range(len(classifiers)):
        # Construct the classifier by unpacking params 
        # store classifier instance
        clf_test = classifiers[i](**params[i])
        # Fit the classifier as usual and call predict_proba
        clf_test.fit(X_train, y_train)
        y_preds_test = clf_test.predict_proba(X_test)
        # Take maximum probability for each class on each classifier 
        # This is done for every instance in X_test
        best_preds_test = np.maximum(best_preds_test, y_preds_test)

    # map the maximum probability for each instance back to its corresponding class
    preds_test = np.array([classes_test[np.argmax(pred)] for pred in best_preds_test])
    return preds_test

# %%
from sklearn.metrics import accuracy_score, f1_score
y_preds_test_sl = ensemble_test(classifiers_sl, params_sl, X_train, y_train_sl, X_test_prepared)
print('Accuracy score = ',accuracy_score(y_test_sl, y_preds_test_sl),'\n',
     'f1_score = ', f1_score(y_test_sl, y_preds_test_sl, average = 'weighted'),'\n',
     'roc_auc_score = ', roc_auc_score(y_test_sl, y_preds_test_sl, average = 'weighted'))
# Out:
# Accuracy score =  0.968503937007874
#  f1_score =  0.9682579118890731
#  roc_auc_score =  0.949147404319818

# %% [markdown]
# ### Generalizing Manual Voting for all Classes

# %%
# parameters for random forest
rfclf_params = {
    'n_estimators': 500, 
    'bootstrap': True, 
    'class_weight':None, 
    'criterion':'gini',
    'max_depth':None, 
    'max_features':'auto',
    'warm_start': True,
    'random_state': 41
    # ... fill in the rest you want here
}

# Fill in svm params here
svm_params = {
    'C': 100,
    'probability':True,
    'random_state':42
}

# KNeighbors params go here
kneighbors_params= {
    'n_neighbors': 5,
    'weights':'distance'
}

# %%
y_test_classes = (y_test_sl, y_test_lim, y_test_shale, y_test_sandlim, y_test_ss, y_test_dol, y_test_sand)
classifiers = [RandomForestClassifier, SVC, KNeighborsClassifier]
params = [rfclf_params, svm_params, kneighbors_params]
y_trains_classes= (y_train_sl, y_train_lim, y_train_shale, y_train_sandlim, 
                   y_train_ss, y_train_dol, y_train_sand)
y_classes_names = ("shaly limestone", "limestone", "shale", "sandy lime", 
                   "shaly sandstone", "dolomite", "sandstone")

# %%
#Just get predictions
for y_trains, y_test, y_strings in zip(y_trains_classes, y_test_classes, y_classes_names):
    y_preds_test = ensemble_test(classifiers, params, X_train, y_trains, X_test_prepared)
    print("\n","Accuracy score for", y_strings, "=", accuracy_score(y_test, y_preds_test))
    print("f1_score for", y_strings, "=", f1_score(y_test, y_preds_test,
                                                        average = 'weighted', labels=np.unique(y_preds_test)))
    print("roc auc score for", y_strings, "=", roc_auc_score(y_test, y_preds_test,
                                                                  average = 'weighted'))
# Out:
#  Accuracy score for shaly limestone = 0.968503937007874
# f1_score for shaly limestone = 0.9682579118890731
# roc auc score for shaly limestone = 0.949147404319818
#
#  Accuracy score for limestone = 0.9553805774278216
# f1_score for limestone = 0.9553805774278216
# roc auc score for limestone = 0.9553871589969688
#
#  Accuracy score for shale = 0.94750656167979
# f1_score for shale = 0.945107272471308
# roc auc score for shale = 0.848170446574702
#
#  Accuracy score for sandy lime = 1.0
# f1_score for sandy lime = 1.0
# roc auc score for sandy lime = 1.0
#
#  Accuracy score for shaly sandstone = 0.9973753280839895
# f1_score for shaly sandstone = 0.9986859395532194
# roc auc score for shaly sandstone = 0.5
#
#  Accuracy score for dolomite = 1.0
# f1_score for dolomite = 1.0
# roc auc score for dolomite = 1.0
#
#  Accuracy score for sandstone = 1.0
# f1_score for sandstone = 1.0
# roc auc score for sandstone = 1.0
